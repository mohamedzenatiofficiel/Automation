# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time
from IPython.display import display

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.implicitly_wait(10)
# Out:
# C:\Users\zmoha\AppData\Local\Temp\ipykernel_1172\3960761795.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
products=[] #List to store name of the product
prices=[] #List to store price of the product
ratings=[] #List to store rating of the product
driver.get("https://www.dealabs.com/nouveaux")

# %%
wait = WebDriverWait(driver, 15)
wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@class="btn btn--mode-primary overflow--wrap-on"]')))
driver.find_element(By.XPATH, '//*[@class="btn btn--mode-primary overflow--wrap-on"]').click()

# %%
try:
    driver.find_element(By.XPATH, '//*[@class="space--h-2 space--fromW3-h-3 aGrid overflow--visible  subNavMenu-btn subNavMenu-hide--menu-selected  cept-filter-popover-trigger"]').click()
    driver.find_element(By.XPATH, '//*[@class="btn btn--mode-transparent btn--mode-transparent--brandPrimary btn--square btn--xs"]').click()
    driver.find_element(By.XPATH, '//*[@class="multiSelect-label size--all-m mute--text"]').click()
    driver.find_element(By.XPATH, "//*[@class='checkbox-text tGrid-cell space--l-2'][.='Ile-de-France ']").click()
    driver.find_element(By.XPATH, "//*[@class='multiSelect-label size--all-m'][.=' 1 Région(s) ']").click()
    driver.find_element(By.XPATH, "//*[@class='btn btn--mode-primary width--all-12 '][.='Enregistrer']").click()
    driver.refresh()
    # driver.execute_script("window.scrollTo(0, -50)") 
    SCROLL_PAUSE_TIME = 10

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

        driver.execute_script("window.scrollTo(0, 50)") 

        time.sleep(SCROLL_PAUSE_TIME)

        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        time.sleep(SCROLL_PAUSE_TIME)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    content = driver.page_source
    print(content)
except Exception:
    print("roooooooh")
    exit()
# Out:
# <html class="height--all-full js svg cssCol no-touch push notification-default body-overlay" lang="fr" data-page="index"><head><meta charset="utf-8"><link rel="dns-prefetch" href="https://www.google-analytics.com/"><link rel="dns-prefetch" href="https://stats.g.doubleclick.net/"><meta name="theme-color" content="#35373B"><meta name="globalsign-domain-verification" content="WhAiI_Ad6wV9FINxA61MSfBwnwGD3M7DJumlMnBQTp"><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no"><meta name="google-site-verification" content=""><meta name="robots" content="max-image-preview:large"><meta property="fb:app_id" content=""><meta name="apple-itunes-app" content="app-id=914813032"><meta name="google-play-app" content="app-id=com.dealabs.apps.android"><meta id="cept-noindex" name="robots" content="noindex, follow"><meta property="og:title" content="Dealabs ⇒ Tous les deals - dealabs.com"><meta property="og:description" content="➤ Les codes promo et offres actuelles ✅ Faites les meilleures affaires ⇒ sur dealabs.com."><meta property="og:site_name" content="Dealabs"><meta property="og:type" content="website"><meta property="og:image" content="https://www.dealabs.com/assets/img/logo-dark_89685.png"><meta property="og:image:secure_url" content="https://www.dealabs.com/assets/img/logo-dark_89685.png"><meta property="og:url" content="https://www.dealabs.com/nouveaux"><meta name="twitter:card" content="summary"><meta name="twitter:title" content="Dealabs ⇒ Tous les deals - dealabs.com"><meta name="twitter:description" content="➤ Les codes promo et offres actuelles ✅ Faites les meilleures affaires ⇒ sur dealabs.com."><meta name="twitter:site" content="@dealabs"><meta name="twitter:image" content="https://www.dealabs.com/assets/img/logo-dark_89685.png"><meta name="description" content="➤ Les codes promo et offres actuelles ✅ Faites les meilleures affaires ⇒ sur dealabs.com."><title>Dealabs ⇒ Tous les deals - dealabs.com</title><link rel="preload" as="style" href="https://www.dealabs.com/assets/css/base_97636a.css"><script>
#       		window.prerenderReady = false;!function(e){var t={};function n(o){if(t[o])return t[o].exports;var r=t[o]={i:o,l:!1,exports:{}};return e[o].call(r.exports,r,r.exports,n),r.l=!0,r.exports}n.m=e,n.c=t,n.d=function(e,t,o){n.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:o})},n.r=function(e){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},n.t=function(e,t){if(1&t&&(e=n(e)),8&t)return e;if(4&t&&"object"==typeof e&&e&&e.__esModule)return e;var o=Object.create(null);if(n.r(o),Object.defineProperty(o,"default",{enumerable:!0,value:e}),2&t&&"string"!=typeof e)for(var r in e)n.d(o,r,function(t){return e[t]}.bind(null,r));return o},n.n=function(e){var t=e&&e.__esModule?function(){return e.default}:function(){return e};return n.d(t,"a",t),t},n.o=function(e,t){return Object.prototype.hasOwnProperty.call(e,t)},n.p="",n(n.s=0)}([function(e,t){!function(e){"use strict";var t=e.documentElement,n=navigator.userAgent;window._polyfilled=[],"IntersectionObserver"in window&&"IntersectionObserverEntry"in window&&"intersectionRatio"in window.IntersectionObserverEntry.prototype&&"isIntersecting"in window.IntersectionObserverEntry.prototype||window._polyfilled.push("IntersectionObserver"),"scrollRestoration"in history&&history.state&&"scrollTo"in history.state&&(history.scrollRestoration="manual"),t.className=function(o){var r=e.createElement("div").style;function i(){var e,t=arguments.length>0&&void 0!==arguments[0]?arguments[0]:1,o=(e=n.match(/Firefox\/([\d]+)/))&&Number(e[1])||-1;return o>=t}if(o=o.replace("no-js","js"),o+=!e.implementation.hasFeature("http://www.w3.org/TR/SVG11/feature#Image","1.1")||/Trident|Edge/.test(n)||i()&&/Windows NT/.test(n)?" no-svg":" svg",o+="columnCount"in r||"webkitColumnCount"in r||"MozColumnCount"in r?" cssCol":" no-cssCol",o+="ontouchstart"in window||navigator.MaxTouchPoints>0||navigator.msMaxTouchPoints>0?" touch":" no-touch",o+="serviceWorker"in navigator&&"PushManager"in window&&(function(){var e,t=arguments.length>0&&void 0!==arguments[0]?arguments[0]:1,o=(e=n.match(/Chrome\/([\d]+)/))&&Number(e[1])||-1;return o>=t&&!/Edge/.test(n)&&!/OPR/.test(n)}(51)||i(45))||window.safari&&window.safari.pushNotification?" push":" no-push","Notification"in window){var a=Notification.permission;setInterval((function(){a!==Notification.permission&&(a=Notification.permission,t.className=t.className.replace(/notification-\w+/,"notification-"+a))}),2e3),o+=" notification-"+a}else o+=" notification-absent";return!/Safari/.test(n)||/Chrome/.test(n)||/OPR/.test(n)||(o+=" safari"),o+=navigator.userAgent.match(/(iPod|iPhone|iPad)/)&&navigator.userAgent.match(/AppleWebKit/)?" no-body-overlay":" body-overlay",e.queryCommandSupported&&e.queryCommandSupported("copy")||(o+=" copy-command-off"),o}(t.className);var o=e.createElement("script");if(!("noModule"in o)&&"onbeforeload"in o){var r=!1;e.addEventListener("beforeload",(function(e){if(e.target===o)r=!0;else if(!e.target.hasAttribute("nomodule")||!r)return;e.preventDefault()}),!0),o.type="module",o.src=".",e.head.appendChild(o),o.remove()}}(document)}]);</script><meta property="prt" content="1666459469"><script type="module">if("serviceWorker" in navigator){navigator.serviceWorker.register("/sw.mdn.js").catch(console.log);}</script><script nomodule="">if("serviceWorker" in navigator){navigator.serviceWorker.register("/sw.lgy.js").catch(console.log);}</script><link rel="stylesheet" href="https://www.dealabs.com/assets/css/base_97636a.css"><link rel="canonical" href="https://www.dealabs.com/nouveaux"><link rel="shortcut icon" href="/favicon.ico" type="image/x-icon"><link rel="apple-touch-icon" href="https://www.dealabs.com/assets/img/appicon_6f27a.png"><script>window.googletag = window.googletag || {cmd: []};
# googletag.cmd.push(function() {
# 	googletag.pubads().setTargeting('g_fr', 'null');
# 	googletag.pubads().setTargeting('u', 'Guest');
# 	googletag.pubads().enableLazyLoad({
# 		fetchMarginPercent: 400,
# 		renderMarginPercent: 200,
# 		mobileScaling: 2.0
# 	});
# 	googletag.pubads().enableSingleRequest();
# 	googletag.enableServices();
# });(function() {
# 	function findIframe(window) {
# 		var frames = document.getElementsByTagName('iframe');
# 		var index = frames.length;
#
# 		while (index) {
# 			index -= 1;
# 			if (frames[index].contentWindow === window) return frames[index];
# 		}
# 		return null;
# 	}
#
# 	window.addEventListener('message', function (event) {
# 		if (event.origin !== location.origin) return;
# 		if (event.data === 'nativeAdLoaded') {
# 			var prevViewportWidth = null;
#
# 			var sendViewportWidth = function() {
# 				var viewportWidth = document.documentElement.clientWidth;
# 				if (prevViewportWidth !== viewportWidth) {
# 					event.source.parent.postMessage({ viewportWidth: viewportWidth }, '*');
# 					prevViewportWidth = viewportWidth;
# 				}
# 			};
#
# 			sendViewportWidth();
# 			window.addEventListener('resize', sendViewportWidth);
# 		} else if (event.data.iframeHeight) {
# 			var currentIFrame = findIframe(event.source.parent);
# 			if (currentIFrame !== null) {
# 				currentIFrame.height = event.data.iframeHeight;
# 			}
# 		}
# 	});
# })();</script><script type="module" src="https://www.dealabs.com/assets/js/modern/runtime_f79cda.js"></script><script nomodule="" defer="" src="https://www.dealabs.com/assets/js/legacy/runtime_179d0b.js"></script><script type="module" src="https://www.dealabs.com/assets/js/modern/polyfills_2c2df2.js"></script><script nomodule="" defer="" src="https://www.dealabs.com/assets/js/legacy/polyfills_a799b3.js"></script><script type="module" src="https://www.dealabs.com/assets/js/modern/vendor_9e12af.js"></script><script nomodule="" defer="" src="https://www.dealabs.com/assets/js/legacy/vendor_fc43db.js"></script><script type="module" src="https://www.dealabs.com/assets/js/modern/common_b17b36.js"></script><script nomodule="" defer="" src="https://www.dealabs.com/assets/js/legacy/common_2c6036.js"></script><script type="module" src="https://www.dealabs.com/assets/js/modern/vue_546d10.js"></script><script nomodule="" defer="" src="https://www.dealabs.com/assets/js/legacy/vue_307213.js"></script><script type="module" src="https://www.dealabs.com/assets/js/modern/main_92fc55.js"></script><script nomodule="" defer="" src="https://www.dealabs.com/assets/js/legacy/main_7d6ddb.js"></script><script charset="utf-8" src="/assets/js/modern/2_008939.js"></script><script charset="utf-8" src="/assets/js/modern/1_b7a00c.js"></script><script charset="utf-8" src="/assets/js/modern/3_cc7eb1.js"></script><script charset="utf-8" src="/assets/js/modern/4_62abb2.js"></script><script charset="utf-8" src="/assets/js/modern/index_bb04fb.js"></script><script charset="utf-8" src="/assets/js/modern/vapid_6fe7c0.js"></script><script charset="utf-8" src="/assets/js/modern/footer_e42009.js"></script><script async="" src="https://static.hotjar.com/c/hotjar-1869599.js?sv=6"></script><script charset="utf-8" src="/assets/js/modern/151_3fbeb7.js"></script><script charset="utf-8" src="/assets/js/modern/149_cad342.js"></script><script charset="utf-8" src="/assets/js/modern/148_73552e.js"></script><script charset="utf-8" src="/assets/js/modern/faye-browser_6a1c1c.js"></script></head><body class="page text--color-charcoal height--all-full"><!----><!----><svg width="189" height="55" viewBox="0 0 189 55" preserveAspectRatio="xMinYMid" xmlns="http://www.w3.org/2000/svg" aria-hidden="true" id="skeleton-item-type-a" style="position: absolute; width:0; height: 0;"><path fill-rule="evenodd" clip-rule="evenodd" d="M4 0C1.79086 0 0 1.79086 0 4V51C0 53.2091 1.79086 55 4 55H51C53.2091 55 55 53.2091 55 51V4C55 1.79086 53.2091 0 51 0H4ZM65 20C63.8954 20 63 20.8954 63 22V29C63 30.1046 63.8954 31 65 31H187C188.105 31 189 30.1046 189 29V22C189 20.8954 188.105 20 187 20H65ZM63 5C63 3.89543 63.8954 3 65 3H187C188.105 3 189 3.89543 189 5V12C189 13.1046 188.105 14 187 14H65C63.8954 14 63 13.1046 63 12V5ZM65 37C63.8954 37 63 37.8954 63 39V46C63 47.1046 63.8954 48 65 48H131C132.105 48 133 47.1046 133 46V39C133 37.8954 132.105 37 131 37H65Z" fill="#E9EAED"></path></svg><svg width="140" height="53" viewBox="0 0 140 53" preserveAspectRatio="xMinYMid" xmlns="http://www.w3.org/2000/svg" aria-hidden="true" id="skeleton-item-type-f" style="position: absolute; width:0; height: 0;"><rect width="140" height="53" rx="5" fill="#E9EAED"></rect></svg><svg width="126" height="15" viewBox="0 0 126 15" preserveAspectRatio="xMinYMid" xmlns="http://www.w3.org/2000/svg" aria-hidden="true" id="skeleton-line" style="position: absolute; width:0; height: 0;"><rect width="126" height="15" rx="2" fill="#E9EAED"></rect></svg><svg width="150" height="32" viewBox="0 0 150 32" preserveAspectRatio="xMinYMid" xmlns="http://www.w3.org/2000/svg" aria-hidden="true" id="skeleton-item-type-d" style="position: absolute; width:0; height: 0;"><rect width="150" height="32" rx="2" fill="#E9EAED"></rect></svg><main id="main" class="bg--off tGrid width--all-12 height--all-full"><div class="tGrid-row"><div id="nav-layer-top" class="hide--empty"></div><div></div><ul id="messages-list" class="messages js-sticky forceLayer" style="position: f ...
# 		1
# 	</span></span><span class="space--h-2 space--fromW3-h-3 aGrid overflow--visible  subNavMenu-btn subNavMenu-hide--menu-unselected"><svg width="20px" height="20px" class="icon icon--filter"><use xlink:href="/assets/img/ico_0764e.svg#filter"></use></svg><span class="hide--toW3 space--l-2">Filtrer</span><span class="cept-selected-filter-count space--ml-1 circle--s subNavMenu-roundCounter-text aGrid-item--toW3 aGrid-item--t-n7 aGrid-item--r-n7 circle--xs--toW3 space--fromW3-ml-2 boxShadow--outline">
# 		1
# 	</span></span></span><script type="text/html" class="subNavMenu-layer"><ul class="subNavMenu-list"
# 						data-track='{&quot;category&quot;:&quot;subnav_bar&quot;}'
# 			><li class="subNavMenu-item--separator space--l-3 space--r-2"><div class="flex width--all-12 boxAlign-jc--all-sb"><div class="lbox--v-8"><span class="subNavMenu-text mute--text space--r-1">Voir :</span></div><form
# 	action="https://www.dealabs.com/nouveaux"
# 	method="post"
# 	class="lbox--v-8"
# ><input
# 		type="hidden"
# 		name="_token"
# 		value="8PPx0ZHBXWHDc6K4EtkpudLdRAgqGyHfE5LqG8fg" /><button
# 				name="layout"
# 				value="horizontal"
# 				title="Afficher les deals en vue liste"
# 				class="cept-layoutBtn-list"
# 							><span class="btn btn--square btn--noColor"><svg width="19px" height="16px" class="icon icon--list text--color-subNavLayerActive"><use xlink:href="/assets/img/ico_0764e.svg#list"></use></svg></span></button><button
# 				name="layout"
# 				value="text"
# 				title="Afficher les deals en vue texte seul"
# 				class="cept-layoutBtn-text"
# 				 data-handler="track ocular" data-track='{"action":"goto_view_","beacon":true}' data-ocular='{"event":"goto_view_"}'			><span class="btn btn--square btn--noColor"><svg width="18px" height="16px" class="icon icon--rows text--color-subNavLayerText"><use xlink:href="/assets/img/ico_0764e.svg#rows"></use></svg></span></button></form></div></li><li><form
# 						action="https://www.dealabs.com/user/filter-settings"
# 						method="post" data-handler="submit" data-submit='{"replaces":[{"key":null,"seal":{"keep":true}}],"triggerData":{"redirect":"."},"onChange":true}'><ul><li class="flex boxAlign-jc--all-sb boxAlign-ai--all-c space--h-3 space--v-2 subNavMenu-item--separator"><span class="subNavMenu-text mute--text space--r-2 overflow--wrap-off">Masquer les éléments expirés</span><input type="hidden" name="hide_expired" value="0"><label class="checkbox size--all-m checkbox--brand checkbox--mode-special "><input class="input checkbox-input checkbox--brand checkbox--mode-special-input" name="hide_expired" id="filterForm-hide_expired" data-handler="focus-toggle track" data-focus-toggle='{"toggles":[{"className":"formList-label--focus","target":".formList-row/.formList-label"}]}' data-track='{"action":"toggle_hide_expired","label":"engagement"}' value="1" type="checkbox"/><span class="tGrid-cell tGrid-cell--shrink"><span class="checkbox-box flex--inline boxAlign-jc--all-c boxAlign-ai--all-c"><svg width="20px" height="16px" class="icon icon--tick text--color-white checkbox-tick"><use xlink:href="/assets/img/ico_0764e.svg#tick"></use></svg></span></span></label></li><li class="flex boxAlign-jc--all-sb boxAlign-ai--all-c space--h-3 space--v-2 subNavMenu-item--separator"><span class="subNavMenu-text mute--text space--r-2 overflow--wrap-off">Masquer les images NSFW</span><input type="hidden" name="hide_nsfw" value="0"><label class="checkbox size--all-m checkbox--brand checkbox--mode-special  cept-filterOptions-nsfw"><input class="input checkbox-input checkbox--brand checkbox--mode-special-input" name="hide_nsfw" id="filterForm-hide_nsfw" data-handler="focus-toggle login" data-focus-toggle='{"toggles":[{"className":"formList-label--focus","target":".formList-row/.formList-label"}]}' data-login='{"source":"hide_nsfw","keyword":"hide_nsfw"}' value="1" type="checkbox" checked/><span class="tGrid-cell tGrid-cell--shrink"><span class="checkbox-box flex--inline boxAlign-jc--all-c boxAlign-ai--all-c"><svg width="20px" height="16px" class="icon icon--tick text--color-white checkbox-tick"><use xlink:href="/assets/img/ico_0764e.svg#tick"></use></svg></span></span></label></li><li class="flex boxAlign-jc--all-sb boxAlign-ai--all-c space--h-3 space--v-2 subNavMenu-item--separator"><span class="subNavMenu-text mute--text space--r-2 overflow--wrap-off">Masquer les deals locaux</span><input type="hidden" name="hide_local" value="0"><label class="checkbox size--all-m checkbox--brand checkbox--mode-special "><input class="input checkbox-input checkbox--brand checkbox--mode-special-input" name="hide_local" id="filterForm-hide_local" data-handler="focus-toggle track" data-focus-toggle='{"toggles":[{"className":"formList-label--focus","target":".formList-row/.formList-label"}]}' data-track='{"action":"toggle_hide_local","label":"engagement"}' value="1" type="checkbox"/><span class="tGrid-cell tGrid-cell--shrink"><span class="checkbox-box flex--inline boxAlign-jc--all-c boxAlign-ai--all-c"><svg width="20px" height="16px" class="icon icon--tick text--color-white checkbox-tick"><use xlink:href="/assets/img/ico_0764e.svg#tick"></use></svg></span></span></label></li></ul></form></li><li class="formList-row"><span class="formList-label"></span><div class="formList-content"><form
# 	id="filter-settings"
# 	method="POST"
# 	action="https://www.dealabs.com/user/filter-settings" data-handler="submit" data-submit='{"replaces":[{"key":null,"seal":{"keep":true}}],"triggerData":{"redirect":"."}}'><div class="space--h-3 "><div  aria-busy="true" class="js-vue2" data-handler="vue2" data-vue2='{"name":"LocationFilter","props":{"value":{"name":"National","id":"1","checked":false,"items":[{"name":"Frontaliers","id":"146","region":null,"parentId":null,"localRegionId":null,"checked":false,"items":[{"name":"Suisse","id":"147","region":"SUI","parentId":146,"localRegionId":"SUI","checked":false,"items":null},{"name":"Allemagne","id":"148","region":"ALM","parentId":146,"localRegionId":"ALM","checked":false,"items":null},{"name":"Belgique","id":"149","region":"BLG","parentId":146,"localRegionId":"BLG","checked":false,"items":null},{"name":"Luxembourg","id":"150","region":"LUX","parentId":146,"localRegionId":"LUX","checked":false,"items":null},{"name":"Espagne","id":"151","region":"ES","parentId":146,"localRegionId":"ES","checked":false,"items":null},{"name":"Italie","id":"152","region":"IT","parentId":146,"localRegionId":"IT","checked":false,"items":null}]},{"name":"Ile-de-France","id":"12","region":null,"parentId":null,"localRegionId":null,"checked":true,"items":[{"name":"Paris","id":"63","region":"75","parentId":12,"localRegionId":"75","checked":true,"items":null},{"name":"Seine-et-Marne","id":"64","region":"77","parentId":12,"localRegionId":"77","checked":true,"items":null},{"name":"Yvelines","id":"65","region":"78","parentId":12,"localRegionId":"78","checked":true,"items":null},{"name":"Essonne","id":"66","region":"91","parentId":12,"localRegionId":"91","checked":true,"items":null},{"name":"Hauts-de-Seine","id":"67","region":"92","parentId":12,"localRegionId":"92","checked":true,"items":null},{"name":"Seine-Saint-Denis","id":"68","region":"93","parentId":12,"localRegionId":"93","checked":true,"items":null},{"name":"Val-de-Marne","id":"69","region":"94","parentId":12,"localRegionId":"94","checked":true,"items":null},{"name":"Val-d\u0027Oise","id":"70","region":"95","parentId":12,"localRegionId":"95","checked":true,"items":null}]},{"name":"Centre-Val de Loire","id":"7","region":null,"parentId":null,"localRegionId":null,"checked":false,"items":[{"name":"Cher","id":"45","region":"18","parentId":7,"localRegionId":"18","checked":false,"items":null},{"name":"Eure-et-Loir","id":"46","region":"28","parentId":7,"localRegionId":"28","checked":false,"items":null},{"name":"Indre","id":"47","region":"36","parentId":7,"localRegionId":"36","checked":false,"items":null},{"name":"Indre-et-Loire","id":"48","region":"37","parentId":7,"localRegionId":"37","checked":false,"items":null},{"name":"Loir-et-Cher","id":"49","region":"41","parentId":7,"localRegionId":"41","checked":false,"items":null},{"name":"Loiret","id":"50","region":"45","parentId":7,"localRegionId":"45","checked":false,"items":null}]},{"name":"Bourgogne-Franche-Comt\u00e9","id":"10","region":null,"parentId":null,"localRegionId":null,"checked":false,"items":[{"name":"C\u00f4te-d\u0027Or","id":"119","region":"21","parentId":10,"localRegionId":"21","checked":false,"items":null},{"name":"Doubs","id":"57","region":"25","parentId":10,"localRegionId":"25","checked":false,"items":null},{"name":"Jura","id":"58","region":"39","parentId":10,"localRegionId":"39","checked":false,"items":null},{"name":"Ni\u00e8vre","id":"120","region":"58","parentId":10,"localRegionId":"58","checked":false,"items":null},{"name":"Haute-Sa\u00f4ne","id":"59","region":"70","parentId":10,"localRegionId":"70","checked":false,"items":null},{"name":"Sa\u00f4ne-et-Loire","id":"121","region":"71","parentId":10,"localRegionId":"71","checked":false,"items":null},{"name":"Yonne","id":"122","region":"89","parentId":10,"localRegionId":"89","checked":false,"items":null},{"name":"Territoire-de-Belfort","id":"60","region":"90","parentId":10,"localRegionId":"90","checked":false,"items":null}]},{"name":"Normandie","id":"4","region":null,"parentId":null,"localRegionI ...
# 		class=""
# 		role="navigation"
# 		aria-label="Pagination"
#
# 						data-track='{&quot;category&quot;:&quot;pagination type:thread&quot;}'
#
# 	><div class="tGrid tGrid--auto overflow--wrap-off text--b text--color-charcoal width--all-12"><span class="tGrid-cell width--all-6 vAlign--all-m"><a href="#" class="" data-handler="scroll-to track" data-track='{"action":"scroll_top","label":"engagement"}'><span class="lbox--v-4 hide--toW3"><svg width="18px" height="12px" class="icon icon--up text--color-brandPrimary space--mr-2 icon-u--1"><use xlink:href="/assets/img/ico_0764e.svg#up"></use></svg>
# 					Haut de page
# 				</span><span class="btn btn--circle btn--mode-grey clickable hide--fromW3 text--color-greyShade" title="Haut de page"><svg width="18px" height="12px" class="icon icon--up icon-u--1"><use xlink:href="/assets/img/ico_0764e.svg#up"></use></svg></span></a></span><span
# 		class="cept-first-page space--r-1 tGrid-cell tGrid-cell--shrink vAlign--all-m text--color-grey"
# 		aria-label="Page"
# 		aria-disabled="true"
# 		disabled
# 	>1</span><span class="tGrid-cell mute--text hAlign--all-l vAlign--all-m space--r-4 tGrid-cell--shrink">…</span><span
# 		class="cept-previous-page lbox--v-4 tGrid-cell tGrid-cell--shrink vAlign--all-m text--color-grey"
# 		aria-label=""
# 		aria-disabled="true"
# 		disabled
# 	><svg width="12px" height="18px" class="icon icon--left"><use xlink:href="/assets/img/ico_0764e.svg#left"></use></svg></span><span class="tGrid-cell tGrid-cell--shrink vAlign--all-m space--h-4 space--v-1 pagination-page"><button
# 						type="button"
# 						class="clickable"
# 						aria-label="Page actuelle"
# 						 data-handler="popover" data-popover='{"target":"#template-pagi-popover","tplData":{"url":"https://www.dealabs.com/nouveaux","currentPage":1,"lastPage":500},"layout":"n","toggleClass":"js-pagi-popover-visible","modifier":"default fade","hideTransition":true,"fixed":null}'
# 					><span class="hide--toW2">Page 1</span><span class="hide--fromW2">1</span></button></span><span class="cept-next-page lbox--v-4 pagination-next tGrid-cell tGrid-cell--shrink vAlign--all-m"><button
# 			rel=""
# 			class="text--color-brandPrimary"
# 			aria-label="Page suivante"
# 			 data-handler="pagination track" data-pagination='{"page":2,"hashtag":""}' data-track='{"action":"goto_next_page","beacon":true}'
# 		><svg width="12px" height="18px" class="icon icon--right"><use xlink:href="/assets/img/ico_0764e.svg#right"></use></svg></button></span><span class="tGrid-cell mute--text hAlign--all-r vAlign--all-m space--l-4 tGrid-cell--shrink">…</span><span class="cept-last-page space--l-1 pagination-page tGrid-cell tGrid-cell--shrink vAlign--all-m"><button
# 			rel="nofollow"
# 			class="text--color-brandPrimary"
# 			aria-label="Page"
# 			 data-handler="pagination track" data-pagination='{"page":500,"hashtag":""}' data-track='{"action":"goto_last_page","beacon":true}'
# 		>
# 			500
# 		</button></span><span class="pagi-toggleFooter tGrid-cell width--all-6 vAlign--all-m hAlign--all-r" role="button" tabindex="0" data-handler="move track" data-move='{"source":"#footer","target":".js-sticky/.pagi-footer","clone":false,"toggles":[{"target":"/ >span","className":"hide"}]}' data-track='{"action":"toggle_footer","label":"engagement"}'><span class="box--all-b"><span class="lbox--v-4 hide--toW3 clickable">
# 					Afficher le footer
# 					<svg width="18px" height="12px" class="icon icon--down text--color-brandPrimary space--ml-2 icon-d--1"><use xlink:href="/assets/img/ico_0764e.svg#down"></use></svg></span><span class="btn btn--circle btn--mode-grey clickable hide--fromW3 text--color-greyShade" title="Afficher le footer"><svg width="18px" height="12px" class="icon icon--down icon-d--1"><use xlink:href="/assets/img/ico_0764e.svg#down"></use></svg></span></span><span class="box--all-b hide"><span class="lbox--v-4 hide--toW3 clickable">
# 					Masquer le footer
# 					<svg width="18px" height="12px" class="icon icon--up text--color-brandPrimary space--ml-2 icon-u--1"><use xlink:href="/assets/img/ico_0764e.svg#up"></use></svg></span><span class="btn btn--circle btn--mode-grey clickable hide--fromW3 text--color-greyShade" title="Masquer le footer"><svg width="18px" height="12px" class="icon icon--up icon-u--1"><use xlink:href="/assets/img/ico_0764e.svg#up"></use></svg></span></span></span></div></nav></script><!----><article id="thread_2426209" class="thread cept-thread-item thread--type-list imgFrame-container--scale thread--deal" data-handler="history thread-click" data-history="{&quot;endpoint&quot;:&quot;https://www.dealabs.com/nouveaux&quot;,&quot;replace&quot;:true,&quot;data&quot;:{&quot;scrollTo&quot;:&quot;#thread_2426209&quot;,&quot;offset&quot;:70,&quot;scrollContainer&quot;:&quot;#main&quot;},&quot;events&quot;:[&quot;history&quot;,&quot;click&quot;],&quot;delegate&quot;:true}" data-ocular="{&quot;thread_ids&quot;:2426209}" data-t="thread" data-t-d="{&quot;id&quot;:2426209}" data-t-view="" data-t-view-twig=""><div class="threadGrid thread-clickRoot"><div class="threadGrid-image space--r-3"><span class="imgFrame imgFrame--noBorder thread-listImgCell"><img alt="Lot de 2 ampoules halogène Osram OS2825-02B - 12V, W5W" class=" thread-image width--all-auto height--all-auto imgFrame-img" src="https://static-pepper.dealabs.com/threads/raw/G1WB4/2426209_1/re/300x300/qt/60/2426209_1.jpg" loading="lazy" width="300" height="451"></span></div><div class="threadGrid-headerMeta"><div class="flex boxAlign-ai--all-c boxAlign-jc--all-sb space--b-2"><div class="cept-vote-box vote-box overflow--hidden border border--color-borderGrey bRad--a thread-noClick"><button type="button" class="space--h-2" title="Vote négatif" data-handler="login delayed-intents" data-login="{&quot;source&quot;:&quot;vote&quot;,&quot;vote&quot;:&quot;down&quot;,&quot;thread_type_translation&quot;:&quot;bons-plans&quot;,&quot;thread_id&quot;:2426209,&quot;thread_slug&quot;:&quot;lot-de-2-ampoules-osram-w5w-12v&quot;,&quot;trackAction&quot;:&quot;vote_down&quot;}" data-delayed-intents="{&quot;intent&quot;:&quot;TV&quot;,&quot;target&quot;:{&quot;2426209&quot;:&quot;down&quot;}}" data-contextual-message="{&quot;target&quot;:&quot;.thread\/.js-contextual-message-placeholder&quot;,&quot;identifier&quot;:&quot;vote&quot;,&quot;layout&quot;:[{&quot;preset&quot;:&quot;s&quot;,&quot;top&quot;:{&quot;offset&quot;:8},&quot;x&quot;:0},{&quot;preset&quot;:&quot;n&quot;,&quot;bottom&quot;:{&quot;offset&quot;:-8},&quot;x&quot;:0}]}"><span class="vote-btn vote-down btn btn--xs btn--circle"><svg width="16px" height="4px" class="icon icon--minus"><use xlink:href="/assets/img/ico_0764e.svg#minus"></use></svg></span></button><span class="cept-vote-temp vote-temp text--color-charcoal">
# 				Nouveau
#
# 	</span><button type="button" class="space--h-2" title="Vote positif" data-handler="login delayed-intents" data-login="{&quot;source&quot;:&quot;vote&quot;,&quot;vote&quot;:&quot;up&quot;,&quot;thread_type_translation&quot;:&quot;bons-plans&quot;,&quot;thread_id&quot;:2426209,&quot;thread_slug&quot;:&quot;lot-de-2-ampoules-osram-w5w-12v&quot;,&quot;trackAction&quot;:&quot;vote_up&quot;}" data-delayed-intents="{&quot;intent&quot;:&quot;TV&quot;,&quot;target&quot;:{&quot;2426209&quot;:&quot;up&quot;}}" data-contextual-message="{&quot;target&quot;:&quot;.thread\/.js-contextual-message-placeholder&quot;,&quot;identifier&quot;:&quot;vote&quot;,&quot;layout&quot;:[{&quot;preset&quot;:&quot;s&quot;,&quot;top&quot;:{&quot;offset&quot;:8},&quot;x&quot;:0},{&quot;preset&quot;:&quot;n&quot;,&quot;bottom&quot;:{&quot;offset&quot;:-8},&quot;x&quot;:0}]}"><span class="vote-btn vote-up btn btn--xs btn--circle"><svg width="16px" height="16px" class="icon icon--plus"><use xlink:href="/assets/img/ico_0764e.svg#plus"></use></svg></span></button></div><div class="size--all-s flex boxAlign-jc--all-fe flex--grow-1 overflow--hidden"><span class="metaRibbon lbox--v-1 overflow--wrap-off space--l-3 text--color-greyShade"><svg width="22px" height="22px" class="icon icon--clock text--color-greyShade space--mr-1"><use xlink:href="/assets/img/ico_0764e.svg#clock"></use></svg><span class="hide--fromW3">3 min</span><span class="hide--toW3">il y a 3 min</span></span></div></div></div><div class="threadGrid-title js-contextual-message-placeholder"><strong class="thread-title "><a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" title="Lot de 2 ampoules halogène Osram OS2825-02B - 12V, W5W" href="https://www.dealabs.com/bons-plans/lot-de-2-ampoules-osram-w5w-12v-2426209" data-t="threadLink" data-t-click="">Lot de 2 ampoules halogène Osram OS2825-02B - 12V, W5W</a></strong><span class="overflow--fade"><span class="overflow--wrap-off"><span class="thread-price text--b cept-tp size--all-l size--fromW3-xl">0,60€</span></span><span class="flex--inline boxAlign-ai--all-c space--ml-2"><span class="mute--text text--lineThrough size--all-l size--fromW3-xl">1,90€</span><span class="space--ml-1 size--all-l size--fromW3-xl">-68%</span></span><span class="text--color-greyShade flex--inline boxAlign-ai--all-c space--ml-2"><svg width="24px" height="18px" class="icon icon--truck"><use xlink:href="/assets/img/ico_0764e.svg#truck"></use></svg><span class="space--ml-2 size--all-s overflow--wrap-off"><span class="hide--toW3"> Gratuit </span><span class="hide--fromW3">Gratuit</span></span></span><span class="thread-divider"></span><a class="text--color-greyShade size--all-s" href="https://www.dealabs.com/codes-promo/amazon" data-handler="ocular" data-ocular="{&quot;event&quot;:&quot;go_to_merchant&quot;,&quot;beacon&quot;:true,&quot;action&quot;:&quot;36_Amazon&quot;}"><span class="overflow--wrap-off">Bons plans <span class="cept-merchant-name text--b text--color-brandPrimary link">Amazon</span></span></a></span></div><div class="threadGrid-body space--v-1"><div class="userHtml userHtml-content"><div class="overflow--wrap-break width--all-12  size--all-s size--fromW3-m" data-handler="lightbox-xhr emoticon-preview" data-lightbox-xhr="{&quot;name&quot;:&quot;threads&quot;}">				Un blister pratique pour remplacer les veilleuses, les feux de plaque, les plafonniers... Pas de quantité minimale à commander cette fois!  (:I
# 				</div></div></div><div class="threadGrid-footerMeta"><div class="footerMeta fGrid width--all-12"><span class="footerMeta-infoSlot lbox--v-4"><span class="c-author lbox--v-3 "><span class="text--b space--mr-1 space--mr-1 thread-user lbox boxAlign-ai--all-c"><span class="box--all-i aGrid"><img class="js-avatar avatar vAlign--all-m  thread-avatar space--mr-1" src="https://static-pepper.dealabs.com/users/raw/default/1339473_2/fi/30x30/qt/80/1339473_2.jpg" alt="Avatar"></span><span class=" thread-username">
# 			jujuledreadu
# 		</span><span class="lbox space--ml-1"></span></span></span></span><span class="footerMeta-actionSlot"><button type="button" class="cept-off box--all-i space--mr-2"><span class="btn btn--mode-boxSec btn--square"><svg width="16" height="20" class="icon icon--bookmark"><use xlink:href="/assets/img/ico_0764e.svg#bookmark"></use></svg></span><!----></button><a class="btn space--h-3 btn--mode-boxSec " href="https://www.dealabs.com/bons-plans/lot-de-2-ampoules-osram-w5w-12v-2426209#comments" title="Commentaires" data-handler="ocular trigger" data-ocular="{&quot;event&quot;:&quot;go_to_comment&quot;,&quot;beacon&quot;:true}" data-trigger="{&quot;triggers&quot;:[{&quot;target&quot;:&quot;article&quot;,&quot;event&quot;:&quot;history&quot;}]}"><svg width="21px" height="20px" class="icon icon--comment space--mr-2"><use xlink:href="/assets/img/ico_0764e.svg#comment"></use></svg><span>0</span></a></span><span class="iGrid-item width--all-12 width--fromW3-auto space--l-0 space--fromW3-l-2 space--t-2 space--fromW3-t-0"><a class="boxAlign-jc--all-c space--h-3 width--all-12 btn btn--mode-primary" href="https://www.dealabs.com/visit/homenew/2426209" target="_blank" rel="nofollow noopener" data-handler="track visit ocular show-app-download-message-onclick" data-track="{&quot;action&quot;:&quot;goto_deal button&quot;,&quot;beacon&quot;:true}" data-visit="{&quot;id&quot;:2426209,&quot;type&quot;:&quot;thread&quot;}" data-ocular="{&quot;event&quot;:&quot;ab_test&quot;,&quot;action&quot;:&quot;click_get_deal&quot;}" data-show-app-download-message-onclick="{&quot;threadTypeId&quot;:1,&quot;isThreadExpired&quot;:false}"><span class="hide--fromW3">Voir le deal</span><span class="hide--toW3">Voir le deal</span><svg width="20px" height="20px" class="icon icon--external space--ml-2"><use xlink:href="/assets/img/ico_0764e.svg#external"></use></svg></a></span></div></div></div></article><article id="thread_2426206" class="thread cept-thread-item thread--type-list imgFrame-container--scale thread--deal" data-handler="history thread-click" data-history="{&quot;endpoint&quot;:&quot;https://www.dealabs.com/nouveaux&quot;,&quot;replace&quot;:true,&quot;data&quot;:{&quot;scrollTo&quot;:&quot;#thread_2426206&quot;,&quot;offset&quot;:70,&quot;scrollContainer&quot;:&quot;#main&quot;},&quot;events&quot;:[&quot;history&quot;,&quot;click&quot;],&quot;delegate&quot;:true}" data-ocular="{&quot;thread_ids&quot;:2426206}" data-t="thread" data-t-d="{&quot;id&quot;:2426206}" data-t-view="" data-t-view-twig=""><div class="threadGrid thread-clickRoot"><div class="threadGrid-image space--r-3"><span class="imgFrame imgFrame--noBorder thread-listImgCell"><img alt="Jeu R-Type Final 2 sur PC (Dématérialisé)" class=" thread-image width--all-auto height--all-auto imgFrame-img" src="https://static-pepper.dealabs.com/threads/raw/DqebI/2426206_1/re/300x300/qt/60/2426206_1.jpg" loading="lazy" width="524" height="300"></span></div><div class="threadGrid-headerMeta"><div class="flex boxAlign-ai--all-c boxAlign-jc--all-sb space--b-2"><div class="cept-vote-box vote-box overflow--hidden border border--color-borderGrey bRad--a thread-noClick"><button type="button" class="space--h-2" title="Vote négatif" data-handler="login delayed-intents" data-login="{&quot;source&quot;:&quot;vote&quot;,&quot;vote&quot;:&quot;down&quot;,&quot;thread_type_translation&quot;:&quot;bons-plans&quot;,&quot;thread_id&quot;:2426206,&quot;thread_slug&quot;:&quot;steam-r-type-final-2-deluxe&quot;,&quot;trackAction&quot;:&quot;vote_down&quot;}" data-delayed-intents="{&quot;intent&quot;:&quot;TV&quot;,&quot;target&quot;:{&quot;2426206&quot;:&quot;down&quot;}}" data-contextual-message="{&quot;target&quot;:&quot;.thread\/.js-contextual-message-placeholder&quot;,&quot;identifier&quot;:&quot;vote&quot;,&quot;layout&quot;:[{&quot;preset&quot;:&quot;s&quot;,&quot;top&quot;:{&quot;offset&quot;:8},&quot;x&quot;:0},{&quot;preset&quot;:&quot;n&quot;,&quot;bottom&quot;:{&quot;offset&quot;:-8},&quot;x&quot;:0}]}"><span class="vote ...
# 					-4°
#
# 	</span><button type="button" class="space--h-2" title="Vote positif" data-handler="login delayed-intents" data-login="{&quot;source&quot;:&quot;vote&quot;,&quot;vote&quot;:&quot;up&quot;,&quot;thread_type_translation&quot;:&quot;bons-plans&quot;,&quot;thread_id&quot;:2426206,&quot;thread_slug&quot;:&quot;steam-r-type-final-2-deluxe&quot;,&quot;trackAction&quot;:&quot;vote_up&quot;}" data-delayed-intents="{&quot;intent&quot;:&quot;TV&quot;,&quot;target&quot;:{&quot;2426206&quot;:&quot;up&quot;}}" data-contextual-message="{&quot;target&quot;:&quot;.thread\/.js-contextual-message-placeholder&quot;,&quot;identifier&quot;:&quot;vote&quot;,&quot;layout&quot;:[{&quot;preset&quot;:&quot;s&quot;,&quot;top&quot;:{&quot;offset&quot;:8},&quot;x&quot;:0},{&quot;preset&quot;:&quot;n&quot;,&quot;bottom&quot;:{&quot;offset&quot;:-8},&quot;x&quot;:0}]}"><span class="vote-btn vote-up btn btn--xs btn--circle"><svg width="16px" height="16px" class="icon icon--plus"><use xlink:href="/assets/img/ico_0764e.svg#plus"></use></svg></span></button></div><div class="size--all-s flex boxAlign-jc--all-fe flex--grow-1 overflow--hidden"><span class="metaRibbon lbox--v-1 overflow--wrap-off space--l-3 text--color-greyShade"><svg width="14px" height="22px" class="icon icon--hourglass text--color-greyShade space--mr-1"><use xlink:href="/assets/img/ico_0764e.svg#hourglass"></use></svg><span class="hide--fromW3"><span class="text--b">31/10/2022</span></span><span class="hide--toW3">Expire le <span class="text--b">31/10/2022</span></span></span><span class="hide--toW2 metaRibbon lbox--v-1 overflow--wrap-off space--l-3 text--color-greyShade"><svg width="22px" height="22px" class="icon icon--clock text--color-greyShade space--mr-1"><use xlink:href="/assets/img/ico_0764e.svg#clock"></use></svg><span class="hide--fromW3">13 min</span><span class="hide--toW3">il y a 13 min</span></span><button type="button" class="metaRibbon-btn space--l-3 clickable hide--fromW2" data-handler="popover" data-popover="{&quot;layout&quot;:&quot;s&quot;,&quot;target&quot;:&quot;#template-ribbons-box-thread-2426206&quot;}"><span class="lbox--v-1 text--color-black"><svg width="18px" height="6px" class="icon icon--overflow"><use xlink:href="/assets/img/ico_0764e.svg#overflow"></use></svg></span></button></div><script id="template-ribbons-box-thread-2426206" type="text/html"><div class="flex boxAlign-jc--all-sb space--mh-3 space--mv-2"><div class="lbox--v-4 popover-title"><span class="">En bref :</span></div><button type="button" class="cept-popover-close linkPlain space--l-3 text--color-greyTint" title="Fermer" data-handler="popover-close"><span class="lbox--v-4"><svg width="16px" height="16px" class="icon icon--cross"><use xlink:href="/assets/img/ico_0764e.svg#cross"></use></svg></span></button></div><ol class="width--all-12 space--h-3 space--b-2"><li class="hide--fromW2 size--all-s text--color-greyShade"><span class="lbox--v-4"><span class="lbox--v-1 lbox--h-3"><svg width="22px" height="22px" class="icon icon--clock text--color-greyShade space--mr-1"><use xlink:href="/assets/img/ico_0764e.svg#clock"></use></svg></span><span>il y a 13 min</span></span></li></ol></script></div></div><div class="threadGrid-title js-contextual-message-placeholder"><strong class="thread-title "><a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" title="Jeu R-Type Final 2 sur PC (Dématérialisé)" href="https://www.dealabs.com/bons-plans/steam-r-type-final-2-deluxe-2426206" data-t="threadLink" data-t-click="">Jeu R-Type Final 2 sur PC (Dématérialisé)</a></strong><span class="overflow--fade"><span class="overflow--wrap-off"><span class="thread-price text--b cept-tp size--all-l size--fromW3-xl">23,99€</span></span><span class="flex--inline boxAlign-ai--all-c space--ml-2"><span class="mute--text text--lineThrough size--all-l size--fromW3-xl">39,99€</span><span class="space--ml-1 size--all-l size--fromW3-xl">-40%</span></span><span class="thread-divider"></span><a class="text--color-greyShade si ...
# 			Gtrevize
# 		</span><span class="lbox space--ml-1"></span></span></span><button class="cept-flag-mobile-source clickable" data-handler="popover track" data-popover="{&quot;layout&quot;:[{&quot;preset&quot;:&quot;n&quot;,&quot;maxWidth&quot;:300}],&quot;modifier&quot;:&quot;default tooltip&quot;,&quot;content&quot;:&quot;<span class=\&quot;lbox--v-2\&quot;><span class=\&quot;hide--touch-off\&quot;>Envoy\u00e9 depuis <a class=\&quot;link\&quot; rel=\&quot;nofollow\&quot; data-handler=\&quot;track\&quot; data-track=\u0027{\&quot;action\&quot;:\&quot;click_popup_link\&quot;,\&quot;label\&quot;:\&quot;engagement\&quot;, \&quot;category\&quot;: \&quot;sent_via_app_icon\&quot;}\u0027 href=\&quot;https://app.adjust.com/i1ux6v9?engagement_type=fallback_click&amp;fallback=https%3A%2F%2Fwww.dealabs.com%2Fapp-download&amp;redirect_macos=https%3A%2F%2Fwww.dealabs.com%2Fapp-download\&quot;> l\u0027app officielle </a></span><span class=\&quot;hide--touch-on\&quot;><a href=\&quot;https://app.adjust.com/i1ux6v9?engagement_type=fallback_click&amp;fallback=https%3A%2F%2Fwww.dealabs.com%2Fapp-download&amp;redirect_macos=https%3A%2F%2Fwww.dealabs.com%2Fapp-download\&quot; class=\&quot;linkPlain\&quot;>Envoy\u00e9 depuis l\u0027app officielle</a></span><button type=\&quot;button\&quot; class=\&quot;linkPlain space--ml-2 text--color-greyTint\&quot; data-handler=\&quot;popover-close\&quot;><span class=\&quot;lbox--v-2\&quot;><svg width=\&quot;16px\&quot; height=\&quot;16px\&quot; class=\&quot;icon icon--cross\&quot;><use xlink:href=\&quot;/assets/img/ico_0764e.svg#cross\&quot;></use></svg></span></button></span>&quot;,&quot;close&quot;:true,&quot;toggles&quot;:[{&quot;className&quot;:&quot;text--color-greyShade text--color-blue&quot;,&quot;target&quot;:&quot;/ .js-flag-mobile-source-ico&quot;}]}" data-track="{&quot;category&quot;:&quot;sent_via_app_icon&quot;,&quot;action&quot;:&quot;click_icon_deal&quot;,&quot;label&quot;:&quot;threadid: 2426206&quot;}"><span class="lbox--v-3"><svg width="15px" height="22px" class="icon icon--mobile text--color-greyShade js-flag-mobile-source-ico"><use xlink:href="/assets/img/ico_0764e.svg#mobile"></use></svg></span></button></span></span><span class="footerMeta-actionSlot"><button type="button" class="cept-off box--all-i space--mr-2"><span class="btn btn--mode-boxSec btn--square"><svg width="16" height="20" class="icon icon--bookmark"><use xlink:href="/assets/img/ico_0764e.svg#bookmark"></use></svg></span><!----></button><a class="btn space--h-3 btn--mode-boxSec " href="https://www.dealabs.com/bons-plans/steam-r-type-final-2-deluxe-2426206#comments" title="Commentaires" data-handler="ocular trigger" data-ocular="{&quot;event&quot;:&quot;go_to_comment&quot;,&quot;beacon&quot;:true}" data-trigger="{&quot;triggers&quot;:[{&quot;target&quot;:&quot;article&quot;,&quot;event&quot;:&quot;history&quot;}]}"><svg width="21px" height="20px" class="icon icon--comment space--mr-2"><use xlink:href="/assets/img/ico_0764e.svg#comment"></use></svg><span>0</span></a></span><span class="iGrid-item width--all-12 width--fromW3-auto space--l-0 space--fromW3-l-2 space--t-2 space--fromW3-t-0"><a class="boxAlign-jc--all-c space--h-3 width--all-12 btn btn--mode-primary" href="https://www.dealabs.com/visit/homenew/2426206" target="_blank" rel="nofollow noopener" data-handler="track visit ocular show-app-download-message-onclick" data-track="{&quot;action&quot;:&quot;goto_deal button&quot;,&quot;beacon&quot;:true}" data-visit="{&quot;id&quot;:2426206,&quot;type&quot;:&quot;thread&quot;}" data-ocular="{&quot;event&quot;:&quot;ab_test&quot;,&quot;action&quot;:&quot;click_get_deal&quot;}" data-show-app-download-message-onclick="{&quot;threadTypeId&quot;:1,&quot;isThreadExpired&quot;:false}"><span class="hide--fromW3">Voir le deal</span><span class="hide--toW3">Voir le deal</span><svg width="20px" height="20px" class="icon icon--external space--ml-2"><use xlink:href="/assets/img/ico_0764e.svg#external"></use></svg></a></span></div></div></div></article><art ...
# 					18°
#
# 	</span><button type="button" class="space--h-2" title="Vote positif" data-handler="login delayed-intents" data-login="{&quot;source&quot;:&quot;vote&quot;,&quot;vote&quot;:&quot;up&quot;,&quot;thread_type_translation&quot;:&quot;bons-plans&quot;,&quot;thread_id&quot;:2426205,&quot;thread_slug&quot;:&quot;levis-mini-crossbody-solid-red-batwing-homme-taille-unique&quot;,&quot;trackAction&quot;:&quot;vote_up&quot;}" data-delayed-intents="{&quot;intent&quot;:&quot;TV&quot;,&quot;target&quot;:{&quot;2426205&quot;:&quot;up&quot;}}" data-contextual-message="{&quot;target&quot;:&quot;.thread\/.js-contextual-message-placeholder&quot;,&quot;identifier&quot;:&quot;vote&quot;,&quot;layout&quot;:[{&quot;preset&quot;:&quot;s&quot;,&quot;top&quot;:{&quot;offset&quot;:8},&quot;x&quot;:0},{&quot;preset&quot;:&quot;n&quot;,&quot;bottom&quot;:{&quot;offset&quot;:-8},&quot;x&quot;:0}]}"><span class="vote-btn vote-up btn btn--xs btn--circle"><svg width="16px" height="16px" class="icon icon--plus"><use xlink:href="/assets/img/ico_0764e.svg#plus"></use></svg></span></button></div><div class="size--all-s flex boxAlign-jc--all-fe flex--grow-1 overflow--hidden"><span class="metaRibbon lbox--v-1 overflow--wrap-off space--l-3 text--color-greyShade"><svg width="22px" height="22px" class="icon icon--clock text--color-greyShade space--mr-1"><use xlink:href="/assets/img/ico_0764e.svg#clock"></use></svg><span class="hide--fromW3">13 min</span><span class="hide--toW3">il y a 13 min</span></span></div></div></div><div class="threadGrid-title js-contextual-message-placeholder"><strong class="thread-title "><a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" title="Sac bandoulière Levi's Mini Crossbody Solid pour Homme - Noir" href="https://www.dealabs.com/bons-plans/levis-mini-crossbody-solid-red-batwing-homme-taille-unique-2426205" data-t="threadLink" data-t-click="">Sac bandoulière Levi's Mini Crossbody Solid pour Homme - Noir</a></strong><span class="overflow--fade"><span class="overflow--wrap-off"><span class="thread-price text--b cept-tp size--all-l size--fromW3-xl">11,99€</span></span><span class="flex--inline boxAlign-ai--all-c space--ml-2"><span class="mute--text text--lineThrough size--all-l size--fromW3-xl">18€</span><span class="space--ml-1 size--all-l size--fromW3-xl">-33%</span></span><span class="text--color-greyShade flex--inline boxAlign-ai--all-c space--ml-2"><svg width="24px" height="18px" class="icon icon--truck"><use xlink:href="/assets/img/ico_0764e.svg#truck"></use></svg><span class="space--ml-2 size--all-s overflow--wrap-off"><span class="hide--toW3"> Gratuit </span><span class="hide--fromW3">Gratuit</span></span></span><span class="thread-divider"></span><a class="text--color-greyShade size--all-s" href="https://www.dealabs.com/codes-promo/amazon" data-handler="ocular" data-ocular="{&quot;event&quot;:&quot;go_to_merchant&quot;,&quot;beacon&quot;:true,&quot;action&quot;:&quot;36_Amazon&quot;}"><span class="overflow--wrap-off">Bons plans <span class="cept-merchant-name text--b text--color-brandPrimary link">Amazon</span></span></a></span></div><div class="threadGrid-body space--v-1"><div class="userHtml userHtml-content"><div class="overflow--wrap-break width--all-12  size--all-s size--fromW3-m" data-handler="lightbox-xhr emoticon-preview" data-lightbox-xhr="{&quot;name&quot;:&quot;threads&quot;}">				Sac à bandoulière fonctionnel idéal pour les sorties du week-end et les balades. Arbore notre logo «&nbsp;chauve-souris&nbsp;» emblématique en rouge.  Couleur regular black
# 				</div></div></div><div class="threadGrid-footerMeta"><div class="footerMeta fGrid width--all-12"><span class="footerMeta-infoSlot lbox--v-4"><span class="flex boxAlign-ai--all-c overflow--ellipsis"><span class="c-author lbox--v-3 "><span class="text--b space--mr-1 space--mr-1 thread-user lbox boxAlign-ai--all-c"><span class="box--all-i aGrid"><img class="js-avatar avatar vAlign--all-m  thread-avatar space--mr-1" src="https://www.dealabs.com/assets/img/profile-listing-placeholder_fecff.png" alt="Avatar"></span><span class=" thread-username">
# 			Daracoco
# ...
# 			type="button"
# 			title="{{cancel}}" data-handler="modal-close"><span class="btn btn--xs btn--square btn--mode-transparent text--color-grey"><svg width="16px" height="16px" class="icon icon--cross"><use xlink:href="/assets/img/ico_0764e.svg#cross"></use></svg></span></button></div><div class="cept-confirm space--h-3 space--b-3">{% if content %}<div class="space--b-3 size--all-m">{{content}}</div>{% endif %}<div class="fGrid"><button
# 				type="button"
# 				class="cept-confirm--cancel width--all-6 fGrid-left" data-handler="modal-close"><span class="btn btn btn--mode-transparent"><span class="flex--width-calc-fix overflow--ellipsis">
# 						{{cancel}}
# 					</span></span></button><button
# 				type="button"
# 				class="cept-confirm--ok width--all-6 fGrid-right" data-handler="trigger modal-close" data-trigger='{"triggers":[{"event":"confirm-ok"}]}'><span class="btn {{btnClass}}"><span class="flex--width-calc-fix overflow--ellipsis">
# 						{{ok}}
# 					</span></span></button></div></div></script><script id="template-progress" type="text/html"><section class="js-progress--cover progress--cover{{coverClasses}}"><span class="progress--content-align"><span class="progress--content"><div class="text--b vAlign--all-m space--b-1{% if error %} vote-temp--burn{% else %} progress--title{% endif %}">
# 						{% if error %}{% else %}
# 							<svg class="spinner  vAlign--all-m" viewBox="0 0 66 66"><circle class="spinner-background" cx="33" cy="33" r="30"></circle><circle class="spinner-bar" cx="33" cy="33" r="30"></circle></svg>						{% endif %}
# 						<span class="space--l-1 vAlign--all-m{% if small %} size--all-m{% else %} size--all-xxl{% endif %}">{{title}}</span></div><div class="progress--bar"><div class="js-progress--indicator progress--indicator{% if error %} vote-temp--burn{% else %} vote-temp--cold{% endif %}" style="width:{{progress}}"></div></div><div><button type="button" class="js-progress--retry progress--retry text--b link link--type-default space--t-1{% if error %}{% else %} hide{% endif %}"><span class="flex boxAlign-ai--all-c space--b-1"><svg width="18px" height="18px" class="icon icon--refresh"><use xlink:href="/assets/img/ico_0764e.svg#refresh"></use></svg><span class="space--l-2 vAlign--all-m{% if small %} size--all-m{% else %} size--all-xxl{% endif %}">{{retry}}</span></span></button><div></div><button type="button" class="js-progress--cancel progress--cancel text--b mute--text space--t-1">{{cancel}}</button></div></span></span></section></script><script id="template-popover" type="text/html"><div class="flex boxAlign-jc--all-sb space--mh-3 space--mv-2"><div class="lbox--v-4 popover-title"><span class="">{{title}}</span></div>{% if noClose %}{% else %}
# 			<button type="button" class="cept-popover-close linkPlain space--l-3 text--color-greyTint" title="Fermer" data-handler="popover-close"><span class="lbox--v-4"><svg width="16px" height="16px" class="icon icon--cross"><use xlink:href="/assets/img/ico_0764e.svg#cross"></use></svg></span></button>{% endif %}</div><div class="space--h-3 space--b-3 size--all-m">{{content}}</div></script><script id="template-popover--simple" type="text/html"><div class="space--h-3 size--all-m">
# 		{{content}}
# 		<button
# 			type="button"
# 			class="linkPlain text--color-grey space--l-3"
# 			title="Fermer" data-handler="popover-close"
# 		><span class="lbox--v-4"><svg width="16px" height="16px" class="icon icon--cross"><use xlink:href="/assets/img/ico_0764e.svg#cross"></use></svg></span></button></div></script><script id="template-popoverLoader" type="text/html"><div class="popover-dummy"><svg class="spinner spinner--centered spinner--size-big" viewBox="0 0 66 66"><circle class="spinner-background" cx="33" cy="33" r="30"></circle><circle class="spinner-bar" cx="33" cy="33" r="30"></circle></svg></div></script><script id="template-modalLoader" type="text/html"><div class="popover-dummyModal"><svg class="spinner spinner--centered spinner--size-big" viewBox="0 0 66 66"><circle class="spinner-background" cx="33" cy="33" r="30"></circle><circle class="spinner-bar" cx="33" cy="33" r="30"></circle></svg></div></script><script id="template-lightbox" type="text/html"><div class="popover-lightbox"
# 						data-track='{&quot;category&quot;:&quot;modal&quot;}'
# 			><div class="height--all-full"><div class="lightbox-spinner space--v-4 space--h-4"><svg class="spinner spinner--centered spinner--size-big" viewBox="0 0 66 66"><circle class="spinner-background" cx="33" cy="33" r="30"></circle><circle class="spinner-bar" cx="33" cy="33" r="30"></circle></svg></div></div></div></script><script id="template-copy-to-clipboard" type="text/html"><div class="space--h-3 space--v-3 flex"><span>Copié dans le presse-papier</span><button
# 			type="button"
# 			class="clickable space--ml-3 text--color-grey"
# 			title="Fermer" data-handler="popover-close"><svg width="16px" height="16px" class="icon icon--cross"><use xlink:href="/assets/img/ico_0764e.svg#cross"></use></svg></button></div></script><script id="template-video-embed" type="text/html"><div class="userHtml-video"><div class="userHtml-video-inner"><iframe class="userHtml-video-iframe" src="{{src}}?autoplay=1" frameborder="0" allowfullscreen></iframe></div></div></script><script>var modulesConfig = {"modules\/push-notifications":{"askGuestPermissionParamsEndpoint":"https:\/\/www.dealabs.com\/bpn\/getRequestPermissionParams","askUserToAllowBrowserPushNotification":null,"isLoggedIn":false,"csrfToken":"8PPx0ZHBXWHDc6K4EtkpudLdRAgqGyHfE5LqG8fg","vapid":{"applicationServerKey":"BIqQnZCL2XuG7k5wRutvtX4AVjV57Et5QFtaVIoDyKAQTf74NzSlgEP+6PKnAqumpm2lVYZMNocp+PfDuMVXCJU=","subscribeUrl":"https:\/\/www.dealabs.com\/bpn\/subscribe-vapid-endpoint"},"apns":{"webServiceUrl":"https:\/\/www.dealabs.com\/bpn","websitePushId":"web.com.dealabs","subscribeUrl":"https:\/\/www.dealabs.com\/bpn\/apple-devices\/registrations"}},"modules\/faye":{"siteEnv":"live-fr","userId":null,"token":"3838fac68b2e2f751d23766a3096d353100fd0930979384d255ea09844fef99d","url":"https:\/\/faye.prod-eks.pepper.com\/faye","isEnabled":true,"waitToConnect":10},"directives\/soft-messages":{"listSelector":"#softMessages-list","itemSelector":".softMessages-item","itemVisibleClassName":"softMessages-item--visible","autoCloseSelector":"[data-soft-message-autoclose]","autoCloseDelay":4000},"directives\/select":{"placeholderClassName":"mute--text"},"directives\/ocular":{"enabled":true,"endpoint":"https:\/\/ocular.dealabs.com\/pixel.gif","data":{"country":"fr","md5Session":"bf19041256fb5818dd2302541218777a"},"allowTracking":true,"proxiedEndpoint":"https:\/\/www.dealabs.com\/ocular\/event"},"modules\/page-tracking":null,"modules\/errors":{"ignoreLoggedOut":0,"text":{"loggedOutError":"Quelque chose n'a pas fonctionn\u00e9 parce que vous n'\u00eates pas connect\u00e9(e). Voulez-vous vous connecter maintenant\u00a0?","failedRequestError":"Une erreur est survenue. Veuillez r\u00e9essayer et recharger la page si le probl\u00e8me persiste."}},"directives\/replace-progress":{"endpoint":null,"target":"","progress":{"progressClass":"progress","text":{"loading":"Chargement\u2026","failed":"\u00c9chec","cancel":"Annuler","retry":"R\u00e9essayer"}}},"vue\/thread-event":{"enabled":true,"filter":{"eventType":"latest","threadType":null,"clearance":null,"expired":null},"pageIds":[2426209,2426206,2426205,2426199,2426198,2426196,2426195,2426193,2426191,2426189,2426190,2426188,2426187,2426186,2426185,2426184,2426183,2424796,2426177,2426178]},"directives\/login":{"isDisabled":0,"disabledMsgTpl":"#template-emergency-msg","endpoint":"https:\/\/www.dealabs.com\/login\/modal\/login"},"directives\/emoticon-preview":{"selector":".emoji","popoverDefaults":{"layout":"n","close":true,"reTrigger":"close"},"tpl":"<div class=\"emoji--size-l space--h-1 space--v-1\">{{emoticon}}<\/div>"},"directives\/datepicker":{"firstDay":1,"format":null,"i18n":{"previousMonth":"Mois pr\u00e9c\u00e9dent","nextMonth":"Mois suivant","months":["Janvier","F\u00e9vrier","Mars","Avril","Mai","Juin","Juillet","Ao\u00fbt","Septembre","Octobre","Novembre","D\u00e9cembre"],"weekdays":["Dimanche","Lundi","Mardi","Mercredi","Jeudi","Vendredi","Samedi"],"weekdaysShort":["Dim","Lun","Mar","Mer","Jeu","Ven","Sam"]}},"directives\/recaptcha":{"sitekey":"6LcUiJIUAAAAAGO2ox8svjTzlgcDGqOU_wE6SCnd","containerClass":"aGrid zIndex--fixed"},"apis\/recaptcha":{"lang":"fr"},"modules\/redirect":{"baseURL":"https:\/\/www.dealabs.com"},"modules\/icon-fallback-system":{"iconURL":"\/assets\/img\/ico_0764e.svg"},"directives\/wysiwyg":{"placeholderHtml":"<svg class=\"spinner spinner--centered spinner--size-big\" viewBox=\"0 0 66 66\">\n\t<circle class=\"spinner-background\" cx=\"33\" cy=\"33\" r=\"30\"><\/circle>\n\t<circle class=\"spinner-bar\" cx=\"33\" cy=\"33\" r=\"30\"><\/circle>\n<\/svg>"},"directives\/dela ...
# 				window.__INITIAL_STATE__ = {"widgets":{"topMerchantsWidget":{"merchants":[{"merchantId":"448","imageUrls":{"avatar.avatar_web_square_38":"\/merchants\/raw\/avatar\/448_2\/re\/38x38\/qt\/70\/448_2.jpg","avatar.avatar_web_square_54":"\/merchants\/raw\/avatar\/448_2\/re\/54x54\/qt\/70\/448_2.jpg","avatar.avatar_web_square_54_2x":"\/merchants\/raw\/avatar\/448_2\/re\/108x108\/qt\/70\/448_2.jpg","avatar.avatar_web_square_94":"\/merchants\/raw\/avatar\/448_2\/re\/94x94\/qt\/70\/448_2.jpg","avatar.avatar_web_square_94_2x":"\/merchants\/raw\/avatar\/448_2\/re\/188x188\/qt\/70\/448_2.jpg"},"logoAlt":"Code promo Honor Store","merchantUrlName":"vmall","merchantName":"Honor Store"},{"merchantId":"13","imageUrls":{"avatar.avatar_web_square_38":"\/merchants\/raw\/avatar\/13_4\/re\/38x38\/qt\/70\/13_4.jpg","avatar.avatar_web_square_54":"\/merchants\/raw\/avatar\/13_4\/re\/54x54\/qt\/70\/13_4.jpg","avatar.avatar_web_square_54_2x":"\/merchants\/raw\/avatar\/13_4\/re\/108x108\/qt\/70\/13_4.jpg","avatar.avatar_web_square_94":"\/merchants\/raw\/avatar\/13_4\/re\/94x94\/qt\/70\/13_4.jpg","avatar.avatar_web_square_94_2x":"\/merchants\/raw\/avatar\/13_4\/re\/188x188\/qt\/70\/13_4.jpg"},"logoAlt":"Code promo AliExpress","merchantUrlName":"aliexpress","merchantName":"AliExpress"},{"merchantId":"1","imageUrls":{"avatar.avatar_web_square_38":"\/merchants\/raw\/avatar\/1_4\/re\/38x38\/qt\/70\/1_4.jpg","avatar.avatar_web_square_54":"\/merchants\/raw\/avatar\/1_4\/re\/54x54\/qt\/70\/1_4.jpg","avatar.avatar_web_square_54_2x":"\/merchants\/raw\/avatar\/1_4\/re\/108x108\/qt\/70\/1_4.jpg","avatar.avatar_web_square_94":"\/merchants\/raw\/avatar\/1_4\/re\/94x94\/qt\/70\/1_4.jpg","avatar.avatar_web_square_94_2x":"\/merchants\/raw\/avatar\/1_4\/re\/188x188\/qt\/70\/1_4.jpg"},"logoAlt":"Code promo Cdiscount","merchantUrlName":"cdiscount","merchantName":"Cdiscount"},{"merchantId":"154","imageUrls":{"avatar.avatar_web_square_38":"\/merchants\/raw\/avatar\/154_3\/re\/38x38\/qt\/70\/154_3.jpg","avatar.avatar_web_square_54":"\/merchants\/raw\/avatar\/154_3\/re\/54x54\/qt\/70\/154_3.jpg","avatar.avatar_web_square_54_2x":"\/merchants\/raw\/avatar\/154_3\/re\/108x108\/qt\/70\/154_3.jpg","avatar.avatar_web_square_94":"\/merchants\/raw\/avatar\/154_3\/re\/94x94\/qt\/70\/154_3.jpg","avatar.avatar_web_square_94_2x":"\/merchants\/raw\/avatar\/154_3\/re\/188x188\/qt\/70\/154_3.jpg"},"logoAlt":"Code promo Lacoste","merchantUrlName":"lacoste","merchantName":"Lacoste"},{"merchantId":"56","imageUrls":{"avatar.avatar_web_square_38":"\/merchants\/raw\/avatar\/56_3\/re\/38x38\/qt\/70\/56_3.jpg","avatar.avatar_web_square_54":"\/merchants\/raw\/avatar\/56_3\/re\/54x54\/qt\/70\/56_3.jpg","avatar.avatar_web_square_54_2x":"\/merchants\/raw\/avatar\/56_3\/re\/108x108\/qt\/70\/56_3.jpg","avatar.avatar_web_square_94":"\/merchants\/raw\/avatar\/56_3\/re\/94x94\/qt\/70\/56_3.jpg","avatar.avatar_web_square_94_2x":"\/merchants\/raw\/avatar\/56_3\/re\/188x188\/qt\/70\/56_3.jpg"},"logoAlt":"Code promo Fnac","merchantUrlName":"fnac","merchantName":"Fnac"},{"merchantId":"7","imageUrls":{"avatar.avatar_web_square_38":"\/merchants\/raw\/avatar\/7_3\/re\/38x38\/qt\/70\/7_3.jpg","avatar.avatar_web_square_54":"\/merchants\/raw\/avatar\/7_3\/re\/54x54\/qt\/70\/7_3.jpg","avatar.avatar_web_square_54_2x":"\/merchants\/raw\/avatar\/7_3\/re\/108x108\/qt\/70\/7_3.jpg","avatar.avatar_web_square_94":"\/merchants\/raw\/avatar\/7_3\/re\/94x94\/qt\/70\/7_3.jpg","avatar.avatar_web_square_94_2x":"\/merchants\/raw\/avatar\/7_3\/re\/188x188\/qt\/70\/7_3.jpg"},"logoAlt":"Code promo adidas","merchantUrlName":"adidas","merchantName":"adidas"},{"merchantId":"2","imageUrls":{"avatar.avatar_web_square_38":"\/merchants\/raw\/avatar\/2_3\/re\/38x38\/qt\/70\/2_3.jpg","avatar.avatar_web_square_54":"\/merchants\/raw\/avatar\/2_3\/re\/54x54\/qt\/70\/2_3.jpg","avatar.avatar_web_square_54_2x":"\/merchants\/raw\/avatar\/2_3\/re\/108x108\/qt\/70\/2_3.jpg","avatar.avatar_web_square_94":"\/merchants\/raw\/avatar\/2_3\/re\/94x94\/qt\/70 ...
# 				window.__RESPONSE_DATA__ = {"thread_listing_view":"list","ocular_pixel_thread_impression_default_params":{"country":"fr","md5Session":"bf19041256fb5818dd2302541218777a","event":"thread_impression","route":"{sort}","route_params":{"sort":"nouveaux"},"ref":"https:\/\/www.dealabs.com\/nouveaux","request_params":[],"is_personalized":"0","page_name":"https:\/\/www.dealabs.com\/nouveaux","page_title":"Dealabs \u21d2 Tous les deals - dealabs.com","page_type":"new_listing"}};
#
#
#
#
#
# (function(w,q){w.GoogleAnalyticsObject=w.ga=function() {q.push(arguments)};w.ga.q=q;w.ga.l=1*new Date();}(window, [["create","UA-26524095-1","dealabs.com",[]],["set","userId",null],["set","anonymizeIp",true],["set","dimension1","new_listing"],["set","dimension2","listing_list"],["set","dimension3",null],["set","dimension4","with"],["set","dimension5","no"],["set","dimension6",0],["set","dimension7",0],["set","dimension8",""],["set","dimension9",0],["set","dimension12",false],["set","dimension13",false],["set","dimension14",false],["send","pageview"]]));
# </script><script src="https://www.google-analytics.com/analytics.js" async=""></script><div id="fb-root"></div></body></html>

# %%
# content = driver.page_source
# content

# %%
soup = BeautifulSoup(content)
soup
# Out:
# <html class="height--all-full js svg cssCol no-touch push notification-default body-overlay" data-page="index" lang="fr"><head><meta charset="utf-8"/><link href="https://www.google-analytics.com/" rel="dns-prefetch"/><link href="https://stats.g.doubleclick.net/" rel="dns-prefetch"/><meta content="#35373B" name="theme-color"/><meta content="WhAiI_Ad6wV9FINxA61MSfBwnwGD3M7DJumlMnBQTp" name="globalsign-domain-verification"/><meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" name="viewport"/><meta content="" name="google-site-verification"/><meta content="max-image-preview:large" name="robots"/><meta content="" property="fb:app_id"/><meta content="app-id=914813032" name="apple-itunes-app"/><meta content="app-id=com.dealabs.apps.android" name="google-play-app"/><meta content="noindex, follow" id="cept-noindex" name="robots"/><meta content="Dealabs ⇒ Tous les deals - dealabs.com" property="og:title"/><meta content="➤ Les codes promo et offres actuelles ✅ Faites les meilleures affaires ⇒ sur dealabs.com." property="og:description"/><meta content="Dealabs" property="og:site_name"/><meta content="website" property="og:type"/><meta content="https://www.dealabs.com/assets/img/logo-dark_89685.png" property="og:image"/><meta content="https://www.dealabs.com/assets/img/logo-dark_89685.png" property="og:image:secure_url"/><meta content="https://www.dealabs.com/nouveaux" property="og:url"/><meta content="summary" name="twitter:card"/><meta content="Dealabs ⇒ Tous les deals - dealabs.com" name="twitter:title"/><meta content="➤ Les codes promo et offres actuelles ✅ Faites les meilleures affaires ⇒ sur dealabs.com." name="twitter:description"/><meta content="@dealabs" name="twitter:site"/><meta content="https://www.dealabs.com/assets/img/logo-dark_89685.png" name="twitter:image"/><meta content="➤ Les codes promo et offres actuelles ✅ Faites les meilleures affaires ⇒ sur dealabs.com." name="description"/><title>Dealabs ⇒ Tous les deals - dealabs.com</title><link as="style" href="https://www.dealabs.com/assets/css/base_97636a.css" rel="preload"/><script>
#       		window.prerenderReady = false;!function(e){var t={};function n(o){if(t[o])return t[o].exports;var r=t[o]={i:o,l:!1,exports:{}};return e[o].call(r.exports,r,r.exports,n),r.l=!0,r.exports}n.m=e,n.c=t,n.d=function(e,t,o){n.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:o})},n.r=function(e){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},n.t=function(e,t){if(1&t&&(e=n(e)),8&t)return e;if(4&t&&"object"==typeof e&&e&&e.__esModule)return e;var o=Object.create(null);if(n.r(o),Object.defineProperty(o,"default",{enumerable:!0,value:e}),2&t&&"string"!=typeof e)for(var r in e)n.d(o,r,function(t){return e[t]}.bind(null,r));return o},n.n=function(e){var t=e&&e.__esModule?function(){return e.default}:function(){return e};return n.d(t,"a",t),t},n.o=function(e,t){return Object.prototype.hasOwnProperty.call(e,t)},n.p="",n(n.s=0)}([function(e,t){!function(e){"use strict";var t=e.documentElement,n=navigator.userAgent;window._polyfilled=[],"IntersectionObserver"in window&&"IntersectionObserverEntry"in window&&"intersectionRatio"in window.IntersectionObserverEntry.prototype&&"isIntersecting"in window.IntersectionObserverEntry.prototype||window._polyfilled.push("IntersectionObserver"),"scrollRestoration"in history&&history.state&&"scrollTo"in history.state&&(history.scrollRestoration="manual"),t.className=function(o){var r=e.createElement("div").style;function i(){var e,t=arguments.length>0&&void 0!==arguments[0]?arguments[0]:1,o=(e=n.match(/Firefox\/([\d]+)/))&&Number(e[1])||-1;return o>=t}if(o=o.replace("no-js","js"),o+=!e.implementation.hasFeature("http://www.w3.org/TR/SVG11/feature#Image","1.1")||/Trident|Edge/.test(n)||i()&&/Windows NT/.test(n)?" no-svg":" svg",o+="columnCount"in r||"webkitColumnCount"in r||"MozColumnCount"in r?" cssCol":" no-cssCol",o+="ontouchstart"in window||navigator.MaxTouchPoints>0||navigator.msMaxTouchPoints>0?" touch":" no-touch",o+="serviceWorker"in navigator&&"PushManager"in window&&(function(){var e,t=arguments.length>0&&void 0!==arguments[0]?arguments[0]:1,o=(e=n.match(/Chrome\/([\d]+)/))&&Number(e[1])||-1;return o>=t&&!/Edge/.test(n)&&!/OPR/.test(n)}(51)||i(45))||window.safari&&window.safari.pushNotification?" push":" no-push","Notification"in window){var a=Notification.permission;setInterval((function(){a!==Notification.permission&&(a=Notification.permission,t.className=t.className.replace(/notification-\w+/,"notification-"+a))}),2e3),o+=" notification-"+a}else o+=" notification-absent";return!/Safari/.test(n)||/Chrome/.test(n)||/OPR/.test(n)||(o+=" safari"),o+=navigator.userAgent.match(/(iPod|iPhone|iPad)/)&&navigator.userAgent.match(/AppleWebKit/)?" no-body-overlay":" body-overlay",e.queryCommandSupported&&e.queryCommandSupported("copy")||(o+=" copy-command-off"),o}(t.className);var o=e.createElement("script");if(!("noModule"in o)&&"onbeforeload"in o){var r=!1;e.addEventListener("beforeload",(function(e){if(e.target===o)r=!0;else if(!e.target.hasAttribute("nomodule")||!r)return;e.preventDefault()}),!0),o.type="module",o.src=".",e.head.appendChild(o),o.remove()}}(document)}]);</script><meta content="1666459469" property="prt"/><script type="module">if("serviceWorker" in navigator){navigator.serviceWorker.register("/sw.mdn.js").catch(console.log);}</script><script nomodule="">if("serviceWorker" in navigator){navigator.serviceWorker.register("/sw.lgy.js").catch(console.log);}</script><link href="https://www.dealabs.com/assets/css/base_97636a.css" rel="stylesheet"/><link href="https://www.dealabs.com/nouveaux" rel="canonical"/><link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://www.dealabs.com/assets/img/appicon_6f27a.png" rel="apple-touch-icon"/><script>window.googletag = window.googletag || {cmd: []};
# googletag.cmd.push(function() {
# 	googletag.pubads().setTargeting('g_fr', 'null');
# 	googletag.pubads().setTargeting('u', 'Guest');
# 	googletag.pubads().enableLazyLoad({
# 		fetchMarginPercent: 400,
# 		renderMarginPercent: 200,
# 		mobileScaling: 2.0
# 	});
# 	googletag.pubads().enableSingleRequest();
# 	googletag.enableServices();
# });(function() {
# 	function findIframe(window) {
# 		var frames = document.getElementsByTagName('iframe');
# 		var index = frames.length;
#
# 		while (index) {
# 			index -= 1;
# 			if (frames[index].contentWindow === window) return frames[index];
# 		}
# 		return null;
# 	}
#
# 	window.addEventListener('message', function (event) {
# 		if (event.origin !== location.origin) return;
# 		if (event.data === 'nativeAdLoaded') {
# 			var prevViewportWidth = null;
#
# 			var sendViewportWidth = function() {
# 				var viewportWidth = document.documentElement.clientWidth;
# 				if (prevViewportWidth !== viewportWidth) {
# 					event.source.parent.postMessage({ viewportWidth: viewportWidth }, '*');
# 					prevViewportWidth = viewportWidth;
# 				}
# 			};
#
# 			sendViewportWidth();
# 			window.addEventListener('resize', sendViewportWidth);
# 		} else if (event.data.iframeHeight) {
# 			var currentIFrame = findIframe(event.source.parent);
# 			if (currentIFrame !== null) {
# 				currentIFrame.height = event.data.iframeHeight;
# 			}
# 		}
# 	});
# })();</script><script src="https://www.dealabs.com/assets/js/modern/runtime_f79cda.js" type="module"></script><script defer="" nomodule="" src="https://www.dealabs.com/assets/js/legacy/runtime_179d0b.js"></script><script src="https://www.dealabs.com/assets/js/modern/polyfills_2c2df2.js" type="module"></script><script defer="" nomodule="" src="https://www.dealabs.com/assets/js/legacy/polyfills_a799b3.js"></script><script src="https://www.dealabs.com/assets/js/modern/vendor_9e12af.js" type="module"></script><script defer="" nomodule="" src="https://www.dealabs.com/assets/js/legacy/vendor_fc43db.js"></script><script src="https://www.dealabs.com/assets/js/modern/common_b17b36.js" type="module"></script><script defer="" nomodule="" src="https://www.dealabs.com/assets/js/legacy/common_2c6036.js"></script><script src="https://www.dealabs.com/assets/js/modern/vue_546d10.js" type="module"></script><script defer="" nomodule="" src="https://www.dealabs.com/assets/js/legacy/vue_307213.js"></script><script src="https://www.dealabs.com/assets/js/modern/main_92fc55.js" type="module"></script><script defer="" nomodule="" src="https://www.dealabs.com/assets/js/legacy/main_7d6ddb.js"></script><script charset="utf-8" src="/assets/js/modern/2_008939.js"></script><script charset="utf-8" src="/assets/js/modern/1_b7a00c.js"></script><script charset="utf-8" src="/assets/js/modern/3_cc7eb1.js"></script><script charset="utf-8" src="/assets/js/modern/4_62abb2.js"></script><script charset="utf-8" src="/assets/js/modern/index_bb04fb.js"></script><script charset="utf-8" src="/assets/js/modern/vapid_6fe7c0.js"></script><script charset="utf-8" src="/assets/js/modern/footer_e42009.js"></script><script async="" src="https://static.hotjar.com/c/hotjar-1869599.js?sv=6"></script><script charset="utf-8" src="/assets/js/modern/151_3fbeb7.js"></script><script charset="utf-8" src="/assets/js/modern/149_cad342.js"></script><script charset="utf-8" src="/assets/js/modern/148_73552e.js"></script><script charset="utf-8" src="/assets/js/modern/faye-browser_6a1c1c.js"></script></head><body class="page text--color-charcoal height--all-full"><!-- --><!-- --><svg aria-hidden="true" height="55" id="skeleton-item-type-a" preserveaspectratio="xMinYMid" style="position: absolute; width:0; height: 0;" viewbox="0 0 189 55" width="189" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M4 0C1.79086 0 0 1.79086 0 4V51C0 53.2091 1.79086 55 4 55H51C53.2091 55 55 53.2091 55 51V4C55 1.79086 53.2091 0 51 0H4ZM65 20C63.8954 20 63 20.8954 63 22V29C63 30.1046 63.8954 31 65 31H187C188.105 31 189 30.1046 189 29V22C189 20.8954 188.105 20 187 20H65ZM63 5C63 3.89543 63.8954 3 65 3H187C188.105 3 189 3.89543 189 5V12C189 13.1046 188.105 14 187 14H65C63.8954 14 63 13.1046 63 12V5ZM65 37C63.8954 37 63 37.8954 63 39V46C63 47.1046 63.8954 48 65 48H131C132.105 48 133 47.1046 133 46V39C133 37.8954 132.105 37 131 37H65Z" fill="#E9EAED" fill-rule="evenodd"></path></svg><svg aria-hidden="true" height="53" id="skeleton-item-type-f" preserveaspectratio="xMinYMid" style="position: absolute; width:0; height: 0;" viewbox="0 0 140 53" width="140" xmlns="http://www.w3.org/2000/svg"><rect fill="#E9EAED" height="53" rx="5" width="140"></rect></svg><svg aria-hidden="true" height="15" id="skeleton-line" preserveaspectratio="xMinYMid" style="position: absolute; width:0; height: 0;" viewbox="0 0 126 15" width="126" xmlns="http://www.w3.org/2000/svg"><rect fill="#E9EAED" height="15" rx="2" width="126"></rect></svg><svg aria-hidden="true" height="32" id="skeleton-item-type-d" preserveaspectratio="xMinYMid" style="position: absolute; width:0; height: 0;" viewbox="0 0 150 32" width="150" xmlns="http://www.w3.org/2000/svg"><rect fill="#E9EAED" height="32" rx="2" width="150"></rect></svg><main class="bg--off tGrid width--all-12 height--all-full" id="main"><div class="tGrid-row"><div class="hide--empty" id="nav-layer-top"></div><div></div><ul class="messages js-sticky forceLayer" id="messages-list" style="position: ...
# 		1
# 	</span></span><span class="space--h-2 space--fromW3-h-3 aGrid overflow--visible subNavMenu-btn subNavMenu-hide--menu-unselected"><svg class="icon icon--filter" height="20px" width="20px"><use xlink:href="/assets/img/ico_0764e.svg#filter"></use></svg><span class="hide--toW3 space--l-2">Filtrer</span><span class="cept-selected-filter-count space--ml-1 circle--s subNavMenu-roundCounter-text aGrid-item--toW3 aGrid-item--t-n7 aGrid-item--r-n7 circle--xs--toW3 space--fromW3-ml-2 boxShadow--outline">
# 		1
# 	</span></span></span><script class="subNavMenu-layer" type="text/html"><ul class="subNavMenu-list"
# 						data-track='{&quot;category&quot;:&quot;subnav_bar&quot;}'
# 			><li class="subNavMenu-item--separator space--l-3 space--r-2"><div class="flex width--all-12 boxAlign-jc--all-sb"><div class="lbox--v-8"><span class="subNavMenu-text mute--text space--r-1">Voir :</span></div><form
# 	action="https://www.dealabs.com/nouveaux"
# 	method="post"
# 	class="lbox--v-8"
# ><input
# 		type="hidden"
# 		name="_token"
# 		value="8PPx0ZHBXWHDc6K4EtkpudLdRAgqGyHfE5LqG8fg" /><button
# 				name="layout"
# 				value="horizontal"
# 				title="Afficher les deals en vue liste"
# 				class="cept-layoutBtn-list"
# 							><span class="btn btn--square btn--noColor"><svg width="19px" height="16px" class="icon icon--list text--color-subNavLayerActive"><use xlink:href="/assets/img/ico_0764e.svg#list"></use></svg></span></button><button
# 				name="layout"
# 				value="text"
# 				title="Afficher les deals en vue texte seul"
# 				class="cept-layoutBtn-text"
# 				 data-handler="track ocular" data-track='{"action":"goto_view_","beacon":true}' data-ocular='{"event":"goto_view_"}'			><span class="btn btn--square btn--noColor"><svg width="18px" height="16px" class="icon icon--rows text--color-subNavLayerText"><use xlink:href="/assets/img/ico_0764e.svg#rows"></use></svg></span></button></form></div></li><li><form
# 						action="https://www.dealabs.com/user/filter-settings"
# 						method="post" data-handler="submit" data-submit='{"replaces":[{"key":null,"seal":{"keep":true}}],"triggerData":{"redirect":"."},"onChange":true}'><ul><li class="flex boxAlign-jc--all-sb boxAlign-ai--all-c space--h-3 space--v-2 subNavMenu-item--separator"><span class="subNavMenu-text mute--text space--r-2 overflow--wrap-off">Masquer les éléments expirés</span><input type="hidden" name="hide_expired" value="0"><label class="checkbox size--all-m checkbox--brand checkbox--mode-special "><input class="input checkbox-input checkbox--brand checkbox--mode-special-input" name="hide_expired" id="filterForm-hide_expired" data-handler="focus-toggle track" data-focus-toggle='{"toggles":[{"className":"formList-label--focus","target":".formList-row/.formList-label"}]}' data-track='{"action":"toggle_hide_expired","label":"engagement"}' value="1" type="checkbox"/><span class="tGrid-cell tGrid-cell--shrink"><span class="checkbox-box flex--inline boxAlign-jc--all-c boxAlign-ai--all-c"><svg width="20px" height="16px" class="icon icon--tick text--color-white checkbox-tick"><use xlink:href="/assets/img/ico_0764e.svg#tick"></use></svg></span></span></label></li><li class="flex boxAlign-jc--all-sb boxAlign-ai--all-c space--h-3 space--v-2 subNavMenu-item--separator"><span class="subNavMenu-text mute--text space--r-2 overflow--wrap-off">Masquer les images NSFW</span><input type="hidden" name="hide_nsfw" value="0"><label class="checkbox size--all-m checkbox--brand checkbox--mode-special  cept-filterOptions-nsfw"><input class="input checkbox-input checkbox--brand checkbox--mode-special-input" name="hide_nsfw" id="filterForm-hide_nsfw" data-handler="focus-toggle login" data-focus-toggle='{"toggles":[{"className":"formList-label--focus","target":".formList-row/.formList-label"}]}' data-login='{"source":"hide_nsfw","keyword":"hide_nsfw"}' value="1" type="checkbox" checked/><span class="tGrid-cell tGrid-cell--shrink"><span class="checkbox-box flex--inline boxAlign-jc--all-c boxAlign-ai--all-c"><svg width="20px" height="16px" class="icon icon--tick text--color-white checkbox-tick"><use xlink:href="/assets/img/ico_0764e.svg#tick"></use></svg></span></span></label></li><li class="flex boxAlign-jc--all-sb boxAlign-ai--all-c space--h-3 space--v-2 subNavMenu-item--separator"><span class="subNavMenu-text mute--text space--r-2 overflow--wrap-off">Masquer les deals locaux</span><input type="hidden" name="hide_local" value="0"><label class="checkbox size--all-m checkbox--brand checkbox--mode-special "><input class="input checkbox-input checkbox--brand checkbox--mode-special-input" name="hide_local" id="filterForm-hide_local" data-handler="focus-toggle track" data-focus-toggle='{"toggles":[{"className":"formList-label--focus","target":".formList-row/.formList-label"}]}' data-track='{"action":"toggle_hide_local","label":"engagement"}' value="1" type="checkbox"/><span class="tGrid-cell tGrid-cell--shrink"><span class="checkbox-box flex--inline boxAlign-jc--all-c boxAlign-ai--all-c"><svg width="20px" height="16px" class="icon icon--tick text--color-white checkbox-tick"><use xlink:href="/assets/img/ico_0764e.svg#tick"></use></svg></span></span></label></li></ul></form></li><li class="formList-row"><span class="formList-label"></span><div class="formList-content"><form
# 	id="filter-settings"
# 	method="POST"
# 	action="https://www.dealabs.com/user/filter-settings" data-handler="submit" data-submit='{"replaces":[{"key":null,"seal":{"keep":true}}],"triggerData":{"redirect":"."}}'><div class="space--h-3 "><div  aria-busy="true" class="js-vue2" data-handler="vue2" data-vue2='{"name":"LocationFilter","props":{"value":{"name":"National","id":"1","checked":false,"items":[{"name":"Frontaliers","id":"146","region":null,"parentId":null,"localRegionId":null,"checked":false,"items":[{"name":"Suisse","id":"147","region":"SUI","parentId":146,"localRegionId":"SUI","checked":false,"items":null},{"name":"Allemagne","id":"148","region":"ALM","parentId":146,"localRegionId":"ALM","checked":false,"items":null},{"name":"Belgique","id":"149","region":"BLG","parentId":146,"localRegionId":"BLG","checked":false,"items":null},{"name":"Luxembourg","id":"150","region":"LUX","parentId":146,"localRegionId":"LUX","checked":false,"items":null},{"name":"Espagne","id":"151","region":"ES","parentId":146,"localRegionId":"ES","checked":false,"items":null},{"name":"Italie","id":"152","region":"IT","parentId":146,"localRegionId":"IT","checked":false,"items":null}]},{"name":"Ile-de-France","id":"12","region":null,"parentId":null,"localRegionId":null,"checked":true,"items":[{"name":"Paris","id":"63","region":"75","parentId":12,"localRegionId":"75","checked":true,"items":null},{"name":"Seine-et-Marne","id":"64","region":"77","parentId":12,"localRegionId":"77","checked":true,"items":null},{"name":"Yvelines","id":"65","region":"78","parentId":12,"localRegionId":"78","checked":true,"items":null},{"name":"Essonne","id":"66","region":"91","parentId":12,"localRegionId":"91","checked":true,"items":null},{"name":"Hauts-de-Seine","id":"67","region":"92","parentId":12,"localRegionId":"92","checked":true,"items":null},{"name":"Seine-Saint-Denis","id":"68","region":"93","parentId":12,"localRegionId":"93","checked":true,"items":null},{"name":"Val-de-Marne","id":"69","region":"94","parentId":12,"localRegionId":"94","checked":true,"items":null},{"name":"Val-d\u0027Oise","id":"70","region":"95","parentId":12,"localRegionId":"95","checked":true,"items":null}]},{"name":"Centre-Val de Loire","id":"7","region":null,"parentId":null,"localRegionId":null,"checked":false,"items":[{"name":"Cher","id":"45","region":"18","parentId":7,"localRegionId":"18","checked":false,"items":null},{"name":"Eure-et-Loir","id":"46","region":"28","parentId":7,"localRegionId":"28","checked":false,"items":null},{"name":"Indre","id":"47","region":"36","parentId":7,"localRegionId":"36","checked":false,"items":null},{"name":"Indre-et-Loire","id":"48","region":"37","parentId":7,"localRegionId":"37","checked":false,"items":null},{"name":"Loir-et-Cher","id":"49","region":"41","parentId":7,"localRegionId":"41","checked":false,"items":null},{"name":"Loiret","id":"50","region":"45","parentId":7,"localRegionId":"45","checked":false,"items":null}]},{"name":"Bourgogne-Franche-Comt\u00e9","id":"10","region":null,"parentId":null,"localRegionId":null,"checked":false,"items":[{"name":"C\u00f4te-d\u0027Or","id":"119","region":"21","parentId":10,"localRegionId":"21","checked":false,"items":null},{"name":"Doubs","id":"57","region":"25","parentId":10,"localRegionId":"25","checked":false,"items":null},{"name":"Jura","id":"58","region":"39","parentId":10,"localRegionId":"39","checked":false,"items":null},{"name":"Ni\u00e8vre","id":"120","region":"58","parentId":10,"localRegionId":"58","checked":false,"items":null},{"name":"Haute-Sa\u00f4ne","id":"59","region":"70","parentId":10,"localRegionId":"70","checked":false,"items":null},{"name":"Sa\u00f4ne-et-Loire","id":"121","region":"71","parentId":10,"localRegionId":"71","checked":false,"items":null},{"name":"Yonne","id":"122","region":"89","parentId":10,"localRegionId":"89","checked":false,"items":null},{"name":"Territoire-de-Belfort","id":"60","region":"90","parentId":10,"localRegionId":"90","checked":false,"items":null}]},{"name":"Normandie","id":"4","region":null,"parentId":null,"localRegionI ...
# 		class=""
# 		role="navigation"
# 		aria-label="Pagination"
#
# 						data-track='{&quot;category&quot;:&quot;pagination type:thread&quot;}'
#
# 	><div class="tGrid tGrid--auto overflow--wrap-off text--b text--color-charcoal width--all-12"><span class="tGrid-cell width--all-6 vAlign--all-m"><a href="#" class="" data-handler="scroll-to track" data-track='{"action":"scroll_top","label":"engagement"}'><span class="lbox--v-4 hide--toW3"><svg width="18px" height="12px" class="icon icon--up text--color-brandPrimary space--mr-2 icon-u--1"><use xlink:href="/assets/img/ico_0764e.svg#up"></use></svg>
# 					Haut de page
# 				</span><span class="btn btn--circle btn--mode-grey clickable hide--fromW3 text--color-greyShade" title="Haut de page"><svg width="18px" height="12px" class="icon icon--up icon-u--1"><use xlink:href="/assets/img/ico_0764e.svg#up"></use></svg></span></a></span><span
# 		class="cept-first-page space--r-1 tGrid-cell tGrid-cell--shrink vAlign--all-m text--color-grey"
# 		aria-label="Page"
# 		aria-disabled="true"
# 		disabled
# 	>1</span><span class="tGrid-cell mute--text hAlign--all-l vAlign--all-m space--r-4 tGrid-cell--shrink">…</span><span
# 		class="cept-previous-page lbox--v-4 tGrid-cell tGrid-cell--shrink vAlign--all-m text--color-grey"
# 		aria-label=""
# 		aria-disabled="true"
# 		disabled
# 	><svg width="12px" height="18px" class="icon icon--left"><use xlink:href="/assets/img/ico_0764e.svg#left"></use></svg></span><span class="tGrid-cell tGrid-cell--shrink vAlign--all-m space--h-4 space--v-1 pagination-page"><button
# 						type="button"
# 						class="clickable"
# 						aria-label="Page actuelle"
# 						 data-handler="popover" data-popover='{"target":"#template-pagi-popover","tplData":{"url":"https://www.dealabs.com/nouveaux","currentPage":1,"lastPage":500},"layout":"n","toggleClass":"js-pagi-popover-visible","modifier":"default fade","hideTransition":true,"fixed":null}'
# 					><span class="hide--toW2">Page 1</span><span class="hide--fromW2">1</span></button></span><span class="cept-next-page lbox--v-4 pagination-next tGrid-cell tGrid-cell--shrink vAlign--all-m"><button
# 			rel=""
# 			class="text--color-brandPrimary"
# 			aria-label="Page suivante"
# 			 data-handler="pagination track" data-pagination='{"page":2,"hashtag":""}' data-track='{"action":"goto_next_page","beacon":true}'
# 		><svg width="12px" height="18px" class="icon icon--right"><use xlink:href="/assets/img/ico_0764e.svg#right"></use></svg></button></span><span class="tGrid-cell mute--text hAlign--all-r vAlign--all-m space--l-4 tGrid-cell--shrink">…</span><span class="cept-last-page space--l-1 pagination-page tGrid-cell tGrid-cell--shrink vAlign--all-m"><button
# 			rel="nofollow"
# 			class="text--color-brandPrimary"
# 			aria-label="Page"
# 			 data-handler="pagination track" data-pagination='{"page":500,"hashtag":""}' data-track='{"action":"goto_last_page","beacon":true}'
# 		>
# 			500
# 		</button></span><span class="pagi-toggleFooter tGrid-cell width--all-6 vAlign--all-m hAlign--all-r" role="button" tabindex="0" data-handler="move track" data-move='{"source":"#footer","target":".js-sticky/.pagi-footer","clone":false,"toggles":[{"target":"/ >span","className":"hide"}]}' data-track='{"action":"toggle_footer","label":"engagement"}'><span class="box--all-b"><span class="lbox--v-4 hide--toW3 clickable">
# 					Afficher le footer
# 					<svg width="18px" height="12px" class="icon icon--down text--color-brandPrimary space--ml-2 icon-d--1"><use xlink:href="/assets/img/ico_0764e.svg#down"></use></svg></span><span class="btn btn--circle btn--mode-grey clickable hide--fromW3 text--color-greyShade" title="Afficher le footer"><svg width="18px" height="12px" class="icon icon--down icon-d--1"><use xlink:href="/assets/img/ico_0764e.svg#down"></use></svg></span></span><span class="box--all-b hide"><span class="lbox--v-4 hide--toW3 clickable">
# 					Masquer le footer
# 					<svg width="18px" height="12px" class="icon icon--up text--color-brandPrimary space--ml-2 icon-u--1"><use xlink:href="/assets/img/ico_0764e.svg#up"></use></svg></span><span class="btn btn--circle btn--mode-grey clickable hide--fromW3 text--color-greyShade" title="Masquer le footer"><svg width="18px" height="12px" class="icon icon--up icon-u--1"><use xlink:href="/assets/img/ico_0764e.svg#up"></use></svg></span></span></span></div></nav></script><!-- --><article class="thread cept-thread-item thread--type-list imgFrame-container--scale thread--deal" data-handler="history thread-click" data-history='{"endpoint":"https://www.dealabs.com/nouveaux","replace":true,"data":{"scrollTo":"#thread_2426209","offset":70,"scrollContainer":"#main"},"events":["history","click"],"delegate":true}' data-ocular='{"thread_ids":2426209}' data-t="thread" data-t-d='{"id":2426209}' data-t-view="" data-t-view-twig="" id="thread_2426209"><div class="threadGrid thread-clickRoot"><div class="threadGrid-image space--r-3"><span class="imgFrame imgFrame--noBorder thread-listImgCell"><img alt="Lot de 2 ampoules halogène Osram OS2825-02B - 12V, W5W" class="thread-image width--all-auto height--all-auto imgFrame-img" height="451" loading="lazy" src="https://static-pepper.dealabs.com/threads/raw/G1WB4/2426209_1/re/300x300/qt/60/2426209_1.jpg" width="300"/></span></div><div class="threadGrid-headerMeta"><div class="flex boxAlign-ai--all-c boxAlign-jc--all-sb space--b-2"><div class="cept-vote-box vote-box overflow--hidden border border--color-borderGrey bRad--a thread-noClick"><button class="space--h-2" data-contextual-message='{"target":".thread\/.js-contextual-message-placeholder","identifier":"vote","layout":[{"preset":"s","top":{"offset":8},"x":0},{"preset":"n","bottom":{"offset":-8},"x":0}]}' data-delayed-intents='{"intent":"TV","target":{"2426209":"down"}}' data-handler="login delayed-intents" data-login='{"source":"vote","vote":"down","thread_type_translation":"bons-plans","thread_id":2426209,"thread_slug":"lot-de-2-ampoules-osram-w5w-12v","trackAction":"vote_down"}' title="Vote négatif" type="button"><span class="vote-btn vote-down btn btn--xs btn--circle"><svg class="icon icon--minus" height="4px" width="16px"><use xlink:href="/assets/img/ico_0764e.svg#minus"></use></svg></span></button><span class="cept-vote-temp vote-temp text--color-charcoal">
# 				Nouveau
#
# 	</span><button class="space--h-2" data-contextual-message='{"target":".thread\/.js-contextual-message-placeholder","identifier":"vote","layout":[{"preset":"s","top":{"offset":8},"x":0},{"preset":"n","bottom":{"offset":-8},"x":0}]}' data-delayed-intents='{"intent":"TV","target":{"2426209":"up"}}' data-handler="login delayed-intents" data-login='{"source":"vote","vote":"up","thread_type_translation":"bons-plans","thread_id":2426209,"thread_slug":"lot-de-2-ampoules-osram-w5w-12v","trackAction":"vote_up"}' title="Vote positif" type="button"><span class="vote-btn vote-up btn btn--xs btn--circle"><svg class="icon icon--plus" height="16px" width="16px"><use xlink:href="/assets/img/ico_0764e.svg#plus"></use></svg></span></button></div><div class="size--all-s flex boxAlign-jc--all-fe flex--grow-1 overflow--hidden"><span class="metaRibbon lbox--v-1 overflow--wrap-off space--l-3 text--color-greyShade"><svg class="icon icon--clock text--color-greyShade space--mr-1" height="22px" width="22px"><use xlink:href="/assets/img/ico_0764e.svg#clock"></use></svg><span class="hide--fromW3">3 min</span><span class="hide--toW3">il y a 3 min</span></span></div></div></div><div class="threadGrid-title js-contextual-message-placeholder"><strong class="thread-title"><a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" data-t="threadLink" data-t-click="" href="https://www.dealabs.com/bons-plans/lot-de-2-ampoules-osram-w5w-12v-2426209" title="Lot de 2 ampoules halogène Osram OS2825-02B - 12V, W5W">Lot de 2 ampoules halogène Osram OS2825-02B - 12V, W5W</a></strong><span class="overflow--fade"><span class="overflow--wrap-off"><span class="thread-price text--b cept-tp size--all-l size--fromW3-xl">0,60€</span></span><span class="flex--inline boxAlign-ai--all-c space--ml-2"><span class="mute--text text--lineThrough size--all-l size--fromW3-xl">1,90€</span><span class="space--ml-1 size--all-l size--fromW3-xl">-68%</span></span><span class="text--color-greyShade flex--inline boxAlign-ai--all-c space--ml-2"><svg class="icon icon--truck" height="18px" width="24px"><use xlink:href="/assets/img/ico_0764e.svg#truck"></use></svg><span class="space--ml-2 size--all-s overflow--wrap-off"><span class="hide--toW3"> Gratuit </span><span class="hide--fromW3">Gratuit</span></span></span><span class="thread-divider"></span><a class="text--color-greyShade size--all-s" data-handler="ocular" data-ocular='{"event":"go_to_merchant","beacon":true,"action":"36_Amazon"}' href="https://www.dealabs.com/codes-promo/amazon"><span class="overflow--wrap-off">Bons plans <span class="cept-merchant-name text--b text--color-brandPrimary link">Amazon</span></span></a></span></div><div class="threadGrid-body space--v-1"><div class="userHtml userHtml-content"><div class="overflow--wrap-break width--all-12 size--all-s size--fromW3-m" data-handler="lightbox-xhr emoticon-preview" data-lightbox-xhr='{"name":"threads"}'>				Un blister pratique pour remplacer les veilleuses, les feux de plaque, les plafonniers... Pas de quantité minimale à commander cette fois!  (:I
# 				</div></div></div><div class="threadGrid-footerMeta"><div class="footerMeta fGrid width--all-12"><span class="footerMeta-infoSlot lbox--v-4"><span class="c-author lbox--v-3"><span class="text--b space--mr-1 space--mr-1 thread-user lbox boxAlign-ai--all-c"><span class="box--all-i aGrid"><img alt="Avatar" class="js-avatar avatar vAlign--all-m thread-avatar space--mr-1" src="https://static-pepper.dealabs.com/users/raw/default/1339473_2/fi/30x30/qt/80/1339473_2.jpg"/></span><span class="thread-username">
# 			jujuledreadu
# 		</span><span class="lbox space--ml-1"></span></span></span></span><span class="footerMeta-actionSlot"><button class="cept-off box--all-i space--mr-2" type="button"><span class="btn btn--mode-boxSec btn--square"><svg class="icon icon--bookmark" height="20" width="16"><use xlink:href="/assets/img/ico_0764e.svg#bookmark"></use></svg></span><!-- --></button><a class="btn space--h-3 btn--mode-boxSec" data-handler="ocular trigger" data-ocular='{"event":"go_to_comment","beacon":true}' data-trigger='{"triggers":[{"target":"article","event":"history"}]}' href="https://www.dealabs.com/bons-plans/lot-de-2-ampoules-osram-w5w-12v-2426209#comments" title="Commentaires"><svg class="icon icon--comment space--mr-2" height="20px" width="21px"><use xlink:href="/assets/img/ico_0764e.svg#comment"></use></svg><span>0</span></a></span><span class="iGrid-item width--all-12 width--fromW3-auto space--l-0 space--fromW3-l-2 space--t-2 space--fromW3-t-0"><a class="boxAlign-jc--all-c space--h-3 width--all-12 btn btn--mode-primary" data-handler="track visit ocular show-app-download-message-onclick" data-ocular='{"event":"ab_test","action":"click_get_deal"}' data-show-app-download-message-onclick='{"threadTypeId":1,"isThreadExpired":false}' data-track='{"action":"goto_deal button","beacon":true}' data-visit='{"id":2426209,"type":"thread"}' href="https://www.dealabs.com/visit/homenew/2426209" rel="nofollow noopener" target="_blank"><span class="hide--fromW3">Voir le deal</span><span class="hide--toW3">Voir le deal</span><svg class="icon icon--external space--ml-2" height="20px" width="20px"><use xlink:href="/assets/img/ico_0764e.svg#external"></use></svg></a></span></div></div></div></article><article class="thread cept-thread-item thread--type-list imgFrame-container--scale thread--deal" data-handler="history thread-click" data-history='{"endpoint":"https://www.dealabs.com/nouveaux","replace":true,"data":{"scrollTo":"#thread_2426206","offset":70,"scrollContainer":"#main"},"events":["history","click"],"delegate":true}' data-ocular='{"thread_ids":2426206}' data-t="thread" data-t-d='{"id":2426206}' data-t-view="" data-t-view-twig="" id="thread_2426206"><div class="threadGrid thread-clickRoot"><div class="threadGrid-image space--r-3"><span class="imgFrame imgFrame--noBorder thread-listImgCell"><img alt="Jeu R-Type Final 2 sur PC (Dématérialisé)" class="thread-image width--all-auto height--all-auto imgFrame-img" height="300" loading="lazy" src="https://static-pepper.dealabs.com/threads/raw/DqebI/2426206_1/re/300x300/qt/60/2426206_1.jpg" width="524"/></span></div><div class="threadGrid-headerMeta"><div class="flex boxAlign-ai--all-c boxAlign-jc--all-sb space--b-2"><div class="cept-vote-box vote-box overflow--hidden border border--color-borderGrey bRad--a thread-noClick"><button class="space--h-2" data-contextual-message='{"target":".thread\/.js-contextual-message-placeholder","identifier":"vote","layout":[{"preset":"s","top":{"offset":8},"x":0},{"preset":"n","bottom":{"offset":-8},"x":0}]}' data-delayed-intents='{"intent":"TV","target":{"2426206":"down"}}' data-handler="login delayed-intents" data-login='{"source":"vote","vote":"down","thread_type_translation":"bons-plans","thread_id":2426206,"thread_slug":"steam-r-type-final-2-deluxe","trackAction":"vote_down"}' title="Vote négatif" type="button"><span class="vote-btn vote-down btn btn--xs btn--circle"><svg class="icon icon--minus" height="4px" width="16px"><use xlink:href="/assets/img/ico_0764e.svg#minus"></use></svg></span></button><span class="cept-vote-temp vote-temp vote-temp--cold">
# 					-4°
#
# 	</span><button class="space--h-2" data-contextual-message='{"target":".thread\/.js-contextual-message-placeholder","identifier":"vote","layout":[{"preset":"s","top":{"offset":8},"x":0},{"preset":"n","bottom":{"offset":-8},"x":0}]}' data-delayed-intents='{"intent":"TV","target":{"2426206":"up"}}' data-handler="login delayed-intents" data-login='{"source":"vote","vote":"up","thread_type_translation":"bons-plans","thread_id":2426206,"thread_slug":"steam-r-type-final-2-deluxe","trackAction":"vote_up"}' title="Vote positif" type="button"><span class="vote-btn vote-up btn btn--xs btn--circle"><svg class="icon icon--plus" height="16px" width="16px"><use xlink:href="/assets/img/ico_0764e.svg#plus"></use></svg></span></button></div><div class="size--all-s flex boxAlign-jc--all-fe flex--grow-1 overflow--hidden"><span class="metaRibbon lbox--v-1 overflow--wrap-off space--l-3 text--color-greyShade"><svg class="icon icon--hourglass text--color-greyShade space--mr-1" height="22px" width="14px"><use xlink:href="/assets/img/ico_0764e.svg#hourglass"></use></svg><span class="hide--fromW3"><span class="text--b">31/10/2022</span></span><span class="hide--toW3">Expire le <span class="text--b">31/10/2022</span></span></span><span class="hide--toW2 metaRibbon lbox--v-1 overflow--wrap-off space--l-3 text--color-greyShade"><svg class="icon icon--clock text--color-greyShade space--mr-1" height="22px" width="22px"><use xlink:href="/assets/img/ico_0764e.svg#clock"></use></svg><span class="hide--fromW3">13 min</span><span class="hide--toW3">il y a 13 min</span></span><button class="metaRibbon-btn space--l-3 clickable hide--fromW2" data-handler="popover" data-popover='{"layout":"s","target":"#template-ribbons-box-thread-2426206"}' type="button"><span class="lbox--v-1 text--color-black"><svg class="icon icon--overflow" height="6px" width="18px"><use xlink:href="/assets/img/ico_0764e.svg#overflow"></use></svg></span></button></div><script id="template-ribbons-box-thread-2426206" type="text/html"><div class="flex boxAlign-jc--all-sb space--mh-3 space--mv-2"><div class="lbox--v-4 popover-title"><span class="">En bref :</span></div><button type="button" class="cept-popover-close linkPlain space--l-3 text--color-greyTint" title="Fermer" data-handler="popover-close"><span class="lbox--v-4"><svg width="16px" height="16px" class="icon icon--cross"><use xlink:href="/assets/img/ico_0764e.svg#cross"></use></svg></span></button></div><ol class="width--all-12 space--h-3 space--b-2"><li class="hide--fromW2 size--all-s text--color-greyShade"><span class="lbox--v-4"><span class="lbox--v-1 lbox--h-3"><svg width="22px" height="22px" class="icon icon--clock text--color-greyShade space--mr-1"><use xlink:href="/assets/img/ico_0764e.svg#clock"></use></svg></span><span>il y a 13 min</span></span></li></ol></script></div></div><div class="threadGrid-title js-contextual-message-placeholder"><strong class="thread-title"><a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" data-t="threadLink" data-t-click="" href="https://www.dealabs.com/bons-plans/steam-r-type-final-2-deluxe-2426206" title="Jeu R-Type Final 2 sur PC (Dématérialisé)">Jeu R-Type Final 2 sur PC (Dématérialisé)</a></strong><span class="overflow--fade"><span class="overflow--wrap-off"><span class="thread-price text--b cept-tp size--all-l size--fromW3-xl">23,99€</span></span><span class="flex--inline boxAlign-ai--all-c space--ml-2"><span class="mute--text text--lineThrough size--all-l size--fromW3-xl">39,99€</span><span class="space--ml-1 size--all-l size--fromW3-xl">-40%</span></span><span class="thread-divider"></span><a class="text--color-greyShade size--all-s" data-handler="ocular" data-ocular='{"event":"go_to_merchant","beacon":true,"action":"28_Steam"}' href="https://www.dealabs.com/codes-promo/steam"><span class="overflow--wrap-off">Bons plans <span class="cept-merchant-name text--b text--color-brandPrimary link">Steam</span></span></a></span></div><div class="threadGrid-body space--v-1"><di ...
# 			Gtrevize
# 		</span><span class="lbox space--ml-1"></span></span></span><button class="cept-flag-mobile-source clickable" data-handler="popover track" data-popover='{"layout":[{"preset":"n","maxWidth":300}],"modifier":"default tooltip","content":"&lt;span class=\"lbox--v-2\"&gt;&lt;span class=\"hide--touch-off\"&gt;Envoy\u00e9 depuis &lt;a class=\"link\" rel=\"nofollow\" data-handler=\"track\" data-track=\u0027{\"action\":\"click_popup_link\",\"label\":\"engagement\", \"category\": \"sent_via_app_icon\"}\u0027 href=\"https://app.adjust.com/i1ux6v9?engagement_type=fallback_click&amp;fallback=https%3A%2F%2Fwww.dealabs.com%2Fapp-download&amp;redirect_macos=https%3A%2F%2Fwww.dealabs.com%2Fapp-download\"&gt; l\u0027app officielle &lt;/a&gt;&lt;/span&gt;&lt;span class=\"hide--touch-on\"&gt;&lt;a href=\"https://app.adjust.com/i1ux6v9?engagement_type=fallback_click&amp;fallback=https%3A%2F%2Fwww.dealabs.com%2Fapp-download&amp;redirect_macos=https%3A%2F%2Fwww.dealabs.com%2Fapp-download\" class=\"linkPlain\"&gt;Envoy\u00e9 depuis l\u0027app officielle&lt;/a&gt;&lt;/span&gt;&lt;button type=\"button\" class=\"linkPlain space--ml-2 text--color-greyTint\" data-handler=\"popover-close\"&gt;&lt;span class=\"lbox--v-2\"&gt;&lt;svg width=\"16px\" height=\"16px\" class=\"icon icon--cross\"&gt;&lt;use xlink:href=\"/assets/img/ico_0764e.svg#cross\"&gt;&lt;/use&gt;&lt;/svg&gt;&lt;/span&gt;&lt;/button&gt;&lt;/span&gt;","close":true,"toggles":[{"className":"text--color-greyShade text--color-blue","target":"/ .js-flag-mobile-source-ico"}]}' data-track='{"category":"sent_via_app_icon","action":"click_icon_deal","label":"threadid: 2426206"}'><span class="lbox--v-3"><svg class="icon icon--mobile text--color-greyShade js-flag-mobile-source-ico" height="22px" width="15px"><use xlink:href="/assets/img/ico_0764e.svg#mobile"></use></svg></span></button></span></span><span class="footerMeta-actionSlot"><button class="cept-off box--all-i space--mr-2" type="button"><span class="btn btn--mode-boxSec btn--square"><svg class="icon icon--bookmark" height="20" width="16"><use xlink:href="/assets/img/ico_0764e.svg#bookmark"></use></svg></span><!-- --></button><a class="btn space--h-3 btn--mode-boxSec" data-handler="ocular trigger" data-ocular='{"event":"go_to_comment","beacon":true}' data-trigger='{"triggers":[{"target":"article","event":"history"}]}' href="https://www.dealabs.com/bons-plans/steam-r-type-final-2-deluxe-2426206#comments" title="Commentaires"><svg class="icon icon--comment space--mr-2" height="20px" width="21px"><use xlink:href="/assets/img/ico_0764e.svg#comment"></use></svg><span>0</span></a></span><span class="iGrid-item width--all-12 width--fromW3-auto space--l-0 space--fromW3-l-2 space--t-2 space--fromW3-t-0"><a class="boxAlign-jc--all-c space--h-3 width--all-12 btn btn--mode-primary" data-handler="track visit ocular show-app-download-message-onclick" data-ocular='{"event":"ab_test","action":"click_get_deal"}' data-show-app-download-message-onclick='{"threadTypeId":1,"isThreadExpired":false}' data-track='{"action":"goto_deal button","beacon":true}' data-visit='{"id":2426206,"type":"thread"}' href="https://www.dealabs.com/visit/homenew/2426206" rel="nofollow noopener" target="_blank"><span class="hide--fromW3">Voir le deal</span><span class="hide--toW3">Voir le deal</span><svg class="icon icon--external space--ml-2" height="20px" width="20px"><use xlink:href="/assets/img/ico_0764e.svg#external"></use></svg></a></span></div></div></div></article><article class="thread cept-thread-item thread--type-list imgFrame-container--scale thread--deal" data-handler="history thread-click" data-history='{"endpoint":"https://www.dealabs.com/nouveaux","replace":true,"data":{"scrollTo":"#thread_2426205","offset":70,"scrollContainer":"#main"},"events":["history","click"],"delegate":true}' data-ocular='{"thread_ids":2426205}' data-t="thread" data-t-d='{"id":2426205}' data-t-view="" data-t-view-twig="" id="thread_2426205"><div class="threadGrid thread-clickRoot"><div class="thread ...
# 					18°
#
# 	</span><button class="space--h-2" data-contextual-message='{"target":".thread\/.js-contextual-message-placeholder","identifier":"vote","layout":[{"preset":"s","top":{"offset":8},"x":0},{"preset":"n","bottom":{"offset":-8},"x":0}]}' data-delayed-intents='{"intent":"TV","target":{"2426205":"up"}}' data-handler="login delayed-intents" data-login='{"source":"vote","vote":"up","thread_type_translation":"bons-plans","thread_id":2426205,"thread_slug":"levis-mini-crossbody-solid-red-batwing-homme-taille-unique","trackAction":"vote_up"}' title="Vote positif" type="button"><span class="vote-btn vote-up btn btn--xs btn--circle"><svg class="icon icon--plus" height="16px" width="16px"><use xlink:href="/assets/img/ico_0764e.svg#plus"></use></svg></span></button></div><div class="size--all-s flex boxAlign-jc--all-fe flex--grow-1 overflow--hidden"><span class="metaRibbon lbox--v-1 overflow--wrap-off space--l-3 text--color-greyShade"><svg class="icon icon--clock text--color-greyShade space--mr-1" height="22px" width="22px"><use xlink:href="/assets/img/ico_0764e.svg#clock"></use></svg><span class="hide--fromW3">13 min</span><span class="hide--toW3">il y a 13 min</span></span></div></div></div><div class="threadGrid-title js-contextual-message-placeholder"><strong class="thread-title"><a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" data-t="threadLink" data-t-click="" href="https://www.dealabs.com/bons-plans/levis-mini-crossbody-solid-red-batwing-homme-taille-unique-2426205" title="Sac bandoulière Levi's Mini Crossbody Solid pour Homme - Noir">Sac bandoulière Levi's Mini Crossbody Solid pour Homme - Noir</a></strong><span class="overflow--fade"><span class="overflow--wrap-off"><span class="thread-price text--b cept-tp size--all-l size--fromW3-xl">11,99€</span></span><span class="flex--inline boxAlign-ai--all-c space--ml-2"><span class="mute--text text--lineThrough size--all-l size--fromW3-xl">18€</span><span class="space--ml-1 size--all-l size--fromW3-xl">-33%</span></span><span class="text--color-greyShade flex--inline boxAlign-ai--all-c space--ml-2"><svg class="icon icon--truck" height="18px" width="24px"><use xlink:href="/assets/img/ico_0764e.svg#truck"></use></svg><span class="space--ml-2 size--all-s overflow--wrap-off"><span class="hide--toW3"> Gratuit </span><span class="hide--fromW3">Gratuit</span></span></span><span class="thread-divider"></span><a class="text--color-greyShade size--all-s" data-handler="ocular" data-ocular='{"event":"go_to_merchant","beacon":true,"action":"36_Amazon"}' href="https://www.dealabs.com/codes-promo/amazon"><span class="overflow--wrap-off">Bons plans <span class="cept-merchant-name text--b text--color-brandPrimary link">Amazon</span></span></a></span></div><div class="threadGrid-body space--v-1"><div class="userHtml userHtml-content"><div class="overflow--wrap-break width--all-12 size--all-s size--fromW3-m" data-handler="lightbox-xhr emoticon-preview" data-lightbox-xhr='{"name":"threads"}'>				Sac à bandoulière fonctionnel idéal pour les sorties du week-end et les balades. Arbore notre logo « chauve-souris » emblématique en rouge.  Couleur regular black
# 				</div></div></div><div class="threadGrid-footerMeta"><div class="footerMeta fGrid width--all-12"><span class="footerMeta-infoSlot lbox--v-4"><span class="flex boxAlign-ai--all-c overflow--ellipsis"><span class="c-author lbox--v-3"><span class="text--b space--mr-1 space--mr-1 thread-user lbox boxAlign-ai--all-c"><span class="box--all-i aGrid"><img alt="Avatar" class="js-avatar avatar vAlign--all-m thread-avatar space--mr-1" src="https://www.dealabs.com/assets/img/profile-listing-placeholder_fecff.png"/></span><span class="thread-username">
# 			Daracoco
# ...
# 			type="button"
# 			title="{{cancel}}" data-handler="modal-close"><span class="btn btn--xs btn--square btn--mode-transparent text--color-grey"><svg width="16px" height="16px" class="icon icon--cross"><use xlink:href="/assets/img/ico_0764e.svg#cross"></use></svg></span></button></div><div class="cept-confirm space--h-3 space--b-3">{% if content %}<div class="space--b-3 size--all-m">{{content}}</div>{% endif %}<div class="fGrid"><button
# 				type="button"
# 				class="cept-confirm--cancel width--all-6 fGrid-left" data-handler="modal-close"><span class="btn btn btn--mode-transparent"><span class="flex--width-calc-fix overflow--ellipsis">
# 						{{cancel}}
# 					</span></span></button><button
# 				type="button"
# 				class="cept-confirm--ok width--all-6 fGrid-right" data-handler="trigger modal-close" data-trigger='{"triggers":[{"event":"confirm-ok"}]}'><span class="btn {{btnClass}}"><span class="flex--width-calc-fix overflow--ellipsis">
# 						{{ok}}
# 					</span></span></button></div></div></script><script id="template-progress" type="text/html"><section class="js-progress--cover progress--cover{{coverClasses}}"><span class="progress--content-align"><span class="progress--content"><div class="text--b vAlign--all-m space--b-1{% if error %} vote-temp--burn{% else %} progress--title{% endif %}">
# 						{% if error %}{% else %}
# 							<svg class="spinner  vAlign--all-m" viewBox="0 0 66 66"><circle class="spinner-background" cx="33" cy="33" r="30"></circle><circle class="spinner-bar" cx="33" cy="33" r="30"></circle></svg>						{% endif %}
# 						<span class="space--l-1 vAlign--all-m{% if small %} size--all-m{% else %} size--all-xxl{% endif %}">{{title}}</span></div><div class="progress--bar"><div class="js-progress--indicator progress--indicator{% if error %} vote-temp--burn{% else %} vote-temp--cold{% endif %}" style="width:{{progress}}"></div></div><div><button type="button" class="js-progress--retry progress--retry text--b link link--type-default space--t-1{% if error %}{% else %} hide{% endif %}"><span class="flex boxAlign-ai--all-c space--b-1"><svg width="18px" height="18px" class="icon icon--refresh"><use xlink:href="/assets/img/ico_0764e.svg#refresh"></use></svg><span class="space--l-2 vAlign--all-m{% if small %} size--all-m{% else %} size--all-xxl{% endif %}">{{retry}}</span></span></button><div></div><button type="button" class="js-progress--cancel progress--cancel text--b mute--text space--t-1">{{cancel}}</button></div></span></span></section></script><script id="template-popover" type="text/html"><div class="flex boxAlign-jc--all-sb space--mh-3 space--mv-2"><div class="lbox--v-4 popover-title"><span class="">{{title}}</span></div>{% if noClose %}{% else %}
# 			<button type="button" class="cept-popover-close linkPlain space--l-3 text--color-greyTint" title="Fermer" data-handler="popover-close"><span class="lbox--v-4"><svg width="16px" height="16px" class="icon icon--cross"><use xlink:href="/assets/img/ico_0764e.svg#cross"></use></svg></span></button>{% endif %}</div><div class="space--h-3 space--b-3 size--all-m">{{content}}</div></script><script id="template-popover--simple" type="text/html"><div class="space--h-3 size--all-m">
# 		{{content}}
# 		<button
# 			type="button"
# 			class="linkPlain text--color-grey space--l-3"
# 			title="Fermer" data-handler="popover-close"
# 		><span class="lbox--v-4"><svg width="16px" height="16px" class="icon icon--cross"><use xlink:href="/assets/img/ico_0764e.svg#cross"></use></svg></span></button></div></script><script id="template-popoverLoader" type="text/html"><div class="popover-dummy"><svg class="spinner spinner--centered spinner--size-big" viewBox="0 0 66 66"><circle class="spinner-background" cx="33" cy="33" r="30"></circle><circle class="spinner-bar" cx="33" cy="33" r="30"></circle></svg></div></script><script id="template-modalLoader" type="text/html"><div class="popover-dummyModal"><svg class="spinner spinner--centered spinner--size-big" viewBox="0 0 66 66"><circle class="spinner-background" cx="33" cy="33" r="30"></circle><circle class="spinner-bar" cx="33" cy="33" r="30"></circle></svg></div></script><script id="template-lightbox" type="text/html"><div class="popover-lightbox"
# 						data-track='{&quot;category&quot;:&quot;modal&quot;}'
# 			><div class="height--all-full"><div class="lightbox-spinner space--v-4 space--h-4"><svg class="spinner spinner--centered spinner--size-big" viewBox="0 0 66 66"><circle class="spinner-background" cx="33" cy="33" r="30"></circle><circle class="spinner-bar" cx="33" cy="33" r="30"></circle></svg></div></div></div></script><script id="template-copy-to-clipboard" type="text/html"><div class="space--h-3 space--v-3 flex"><span>Copié dans le presse-papier</span><button
# 			type="button"
# 			class="clickable space--ml-3 text--color-grey"
# 			title="Fermer" data-handler="popover-close"><svg width="16px" height="16px" class="icon icon--cross"><use xlink:href="/assets/img/ico_0764e.svg#cross"></use></svg></button></div></script><script id="template-video-embed" type="text/html"><div class="userHtml-video"><div class="userHtml-video-inner"><iframe class="userHtml-video-iframe" src="{{src}}?autoplay=1" frameborder="0" allowfullscreen></iframe></div></div></script><script>var modulesConfig = {"modules\/push-notifications":{"askGuestPermissionParamsEndpoint":"https:\/\/www.dealabs.com\/bpn\/getRequestPermissionParams","askUserToAllowBrowserPushNotification":null,"isLoggedIn":false,"csrfToken":"8PPx0ZHBXWHDc6K4EtkpudLdRAgqGyHfE5LqG8fg","vapid":{"applicationServerKey":"BIqQnZCL2XuG7k5wRutvtX4AVjV57Et5QFtaVIoDyKAQTf74NzSlgEP+6PKnAqumpm2lVYZMNocp+PfDuMVXCJU=","subscribeUrl":"https:\/\/www.dealabs.com\/bpn\/subscribe-vapid-endpoint"},"apns":{"webServiceUrl":"https:\/\/www.dealabs.com\/bpn","websitePushId":"web.com.dealabs","subscribeUrl":"https:\/\/www.dealabs.com\/bpn\/apple-devices\/registrations"}},"modules\/faye":{"siteEnv":"live-fr","userId":null,"token":"3838fac68b2e2f751d23766a3096d353100fd0930979384d255ea09844fef99d","url":"https:\/\/faye.prod-eks.pepper.com\/faye","isEnabled":true,"waitToConnect":10},"directives\/soft-messages":{"listSelector":"#softMessages-list","itemSelector":".softMessages-item","itemVisibleClassName":"softMessages-item--visible","autoCloseSelector":"[data-soft-message-autoclose]","autoCloseDelay":4000},"directives\/select":{"placeholderClassName":"mute--text"},"directives\/ocular":{"enabled":true,"endpoint":"https:\/\/ocular.dealabs.com\/pixel.gif","data":{"country":"fr","md5Session":"bf19041256fb5818dd2302541218777a"},"allowTracking":true,"proxiedEndpoint":"https:\/\/www.dealabs.com\/ocular\/event"},"modules\/page-tracking":null,"modules\/errors":{"ignoreLoggedOut":0,"text":{"loggedOutError":"Quelque chose n'a pas fonctionn\u00e9 parce que vous n'\u00eates pas connect\u00e9(e). Voulez-vous vous connecter maintenant\u00a0?","failedRequestError":"Une erreur est survenue. Veuillez r\u00e9essayer et recharger la page si le probl\u00e8me persiste."}},"directives\/replace-progress":{"endpoint":null,"target":"","progress":{"progressClass":"progress","text":{"loading":"Chargement\u2026","failed":"\u00c9chec","cancel":"Annuler","retry":"R\u00e9essayer"}}},"vue\/thread-event":{"enabled":true,"filter":{"eventType":"latest","threadType":null,"clearance":null,"expired":null},"pageIds":[2426209,2426206,2426205,2426199,2426198,2426196,2426195,2426193,2426191,2426189,2426190,2426188,2426187,2426186,2426185,2426184,2426183,2424796,2426177,2426178]},"directives\/login":{"isDisabled":0,"disabledMsgTpl":"#template-emergency-msg","endpoint":"https:\/\/www.dealabs.com\/login\/modal\/login"},"directives\/emoticon-preview":{"selector":".emoji","popoverDefaults":{"layout":"n","close":true,"reTrigger":"close"},"tpl":"<div class=\"emoji--size-l space--h-1 space--v-1\">{{emoticon}}<\/div>"},"directives\/datepicker":{"firstDay":1,"format":null,"i18n":{"previousMonth":"Mois pr\u00e9c\u00e9dent","nextMonth":"Mois suivant","months":["Janvier","F\u00e9vrier","Mars","Avril","Mai","Juin","Juillet","Ao\u00fbt","Septembre","Octobre","Novembre","D\u00e9cembre"],"weekdays":["Dimanche","Lundi","Mardi","Mercredi","Jeudi","Vendredi","Samedi"],"weekdaysShort":["Dim","Lun","Mar","Mer","Jeu","Ven","Sam"]}},"directives\/recaptcha":{"sitekey":"6LcUiJIUAAAAAGO2ox8svjTzlgcDGqOU_wE6SCnd","containerClass":"aGrid zIndex--fixed"},"apis\/recaptcha":{"lang":"fr"},"modules\/redirect":{"baseURL":"https:\/\/www.dealabs.com"},"modules\/icon-fallback-system":{"iconURL":"\/assets\/img\/ico_0764e.svg"},"directives\/wysiwyg":{"placeholderHtml":"<svg class=\"spinner spinner--centered spinner--size-big\" viewBox=\"0 0 66 66\">\n\t<circle class=\"spinner-background\" cx=\"33\" cy=\"33\" r=\"30\"><\/circle>\n\t<circle class=\"spinner-bar\" cx=\"33\" cy=\"33\" r=\"30\"><\/circle>\n<\/svg>"},"directives\/dela ...
# 				window.__INITIAL_STATE__ = {"widgets":{"topMerchantsWidget":{"merchants":[{"merchantId":"448","imageUrls":{"avatar.avatar_web_square_38":"\/merchants\/raw\/avatar\/448_2\/re\/38x38\/qt\/70\/448_2.jpg","avatar.avatar_web_square_54":"\/merchants\/raw\/avatar\/448_2\/re\/54x54\/qt\/70\/448_2.jpg","avatar.avatar_web_square_54_2x":"\/merchants\/raw\/avatar\/448_2\/re\/108x108\/qt\/70\/448_2.jpg","avatar.avatar_web_square_94":"\/merchants\/raw\/avatar\/448_2\/re\/94x94\/qt\/70\/448_2.jpg","avatar.avatar_web_square_94_2x":"\/merchants\/raw\/avatar\/448_2\/re\/188x188\/qt\/70\/448_2.jpg"},"logoAlt":"Code promo Honor Store","merchantUrlName":"vmall","merchantName":"Honor Store"},{"merchantId":"13","imageUrls":{"avatar.avatar_web_square_38":"\/merchants\/raw\/avatar\/13_4\/re\/38x38\/qt\/70\/13_4.jpg","avatar.avatar_web_square_54":"\/merchants\/raw\/avatar\/13_4\/re\/54x54\/qt\/70\/13_4.jpg","avatar.avatar_web_square_54_2x":"\/merchants\/raw\/avatar\/13_4\/re\/108x108\/qt\/70\/13_4.jpg","avatar.avatar_web_square_94":"\/merchants\/raw\/avatar\/13_4\/re\/94x94\/qt\/70\/13_4.jpg","avatar.avatar_web_square_94_2x":"\/merchants\/raw\/avatar\/13_4\/re\/188x188\/qt\/70\/13_4.jpg"},"logoAlt":"Code promo AliExpress","merchantUrlName":"aliexpress","merchantName":"AliExpress"},{"merchantId":"1","imageUrls":{"avatar.avatar_web_square_38":"\/merchants\/raw\/avatar\/1_4\/re\/38x38\/qt\/70\/1_4.jpg","avatar.avatar_web_square_54":"\/merchants\/raw\/avatar\/1_4\/re\/54x54\/qt\/70\/1_4.jpg","avatar.avatar_web_square_54_2x":"\/merchants\/raw\/avatar\/1_4\/re\/108x108\/qt\/70\/1_4.jpg","avatar.avatar_web_square_94":"\/merchants\/raw\/avatar\/1_4\/re\/94x94\/qt\/70\/1_4.jpg","avatar.avatar_web_square_94_2x":"\/merchants\/raw\/avatar\/1_4\/re\/188x188\/qt\/70\/1_4.jpg"},"logoAlt":"Code promo Cdiscount","merchantUrlName":"cdiscount","merchantName":"Cdiscount"},{"merchantId":"154","imageUrls":{"avatar.avatar_web_square_38":"\/merchants\/raw\/avatar\/154_3\/re\/38x38\/qt\/70\/154_3.jpg","avatar.avatar_web_square_54":"\/merchants\/raw\/avatar\/154_3\/re\/54x54\/qt\/70\/154_3.jpg","avatar.avatar_web_square_54_2x":"\/merchants\/raw\/avatar\/154_3\/re\/108x108\/qt\/70\/154_3.jpg","avatar.avatar_web_square_94":"\/merchants\/raw\/avatar\/154_3\/re\/94x94\/qt\/70\/154_3.jpg","avatar.avatar_web_square_94_2x":"\/merchants\/raw\/avatar\/154_3\/re\/188x188\/qt\/70\/154_3.jpg"},"logoAlt":"Code promo Lacoste","merchantUrlName":"lacoste","merchantName":"Lacoste"},{"merchantId":"56","imageUrls":{"avatar.avatar_web_square_38":"\/merchants\/raw\/avatar\/56_3\/re\/38x38\/qt\/70\/56_3.jpg","avatar.avatar_web_square_54":"\/merchants\/raw\/avatar\/56_3\/re\/54x54\/qt\/70\/56_3.jpg","avatar.avatar_web_square_54_2x":"\/merchants\/raw\/avatar\/56_3\/re\/108x108\/qt\/70\/56_3.jpg","avatar.avatar_web_square_94":"\/merchants\/raw\/avatar\/56_3\/re\/94x94\/qt\/70\/56_3.jpg","avatar.avatar_web_square_94_2x":"\/merchants\/raw\/avatar\/56_3\/re\/188x188\/qt\/70\/56_3.jpg"},"logoAlt":"Code promo Fnac","merchantUrlName":"fnac","merchantName":"Fnac"},{"merchantId":"7","imageUrls":{"avatar.avatar_web_square_38":"\/merchants\/raw\/avatar\/7_3\/re\/38x38\/qt\/70\/7_3.jpg","avatar.avatar_web_square_54":"\/merchants\/raw\/avatar\/7_3\/re\/54x54\/qt\/70\/7_3.jpg","avatar.avatar_web_square_54_2x":"\/merchants\/raw\/avatar\/7_3\/re\/108x108\/qt\/70\/7_3.jpg","avatar.avatar_web_square_94":"\/merchants\/raw\/avatar\/7_3\/re\/94x94\/qt\/70\/7_3.jpg","avatar.avatar_web_square_94_2x":"\/merchants\/raw\/avatar\/7_3\/re\/188x188\/qt\/70\/7_3.jpg"},"logoAlt":"Code promo adidas","merchantUrlName":"adidas","merchantName":"adidas"},{"merchantId":"2","imageUrls":{"avatar.avatar_web_square_38":"\/merchants\/raw\/avatar\/2_3\/re\/38x38\/qt\/70\/2_3.jpg","avatar.avatar_web_square_54":"\/merchants\/raw\/avatar\/2_3\/re\/54x54\/qt\/70\/2_3.jpg","avatar.avatar_web_square_54_2x":"\/merchants\/raw\/avatar\/2_3\/re\/108x108\/qt\/70\/2_3.jpg","avatar.avatar_web_square_94":"\/merchants\/raw\/avatar\/2_3\/re\/94x94\/qt\/70 ...
# 				window.__RESPONSE_DATA__ = {"thread_listing_view":"list","ocular_pixel_thread_impression_default_params":{"country":"fr","md5Session":"bf19041256fb5818dd2302541218777a","event":"thread_impression","route":"{sort}","route_params":{"sort":"nouveaux"},"ref":"https:\/\/www.dealabs.com\/nouveaux","request_params":[],"is_personalized":"0","page_name":"https:\/\/www.dealabs.com\/nouveaux","page_title":"Dealabs \u21d2 Tous les deals - dealabs.com","page_type":"new_listing"}};
#
#
#
#
#
# (function(w,q){w.GoogleAnalyticsObject=w.ga=function() {q.push(arguments)};w.ga.q=q;w.ga.l=1*new Date();}(window, [["create","UA-26524095-1","dealabs.com",[]],["set","userId",null],["set","anonymizeIp",true],["set","dimension1","new_listing"],["set","dimension2","listing_list"],["set","dimension3",null],["set","dimension4","with"],["set","dimension5","no"],["set","dimension6",0],["set","dimension7",0],["set","dimension8",""],["set","dimension9",0],["set","dimension12",false],["set","dimension13",false],["set","dimension14",false],["send","pageview"]]));
# </script><script async="" src="https://www.google-analytics.com/analytics.js"></script><div id="fb-root"></div></body></html>

# %%
for a in soup.find_all("div", {"class": "cept-event-deals js-threadList listLayout-main"}):
    name=a.find_all("a", {"class": "cept-tt thread-link linkPlain thread-title--list js-thread-title"})
#     price=a.find('div', attrs={'class':'_1vC4OE _2rQ-NK'})
#     rating=a.find('div', attrs={'class':'hGSR34 _2beYZw'})
    products.append(name)
    print(products)
#     prices.append(price.text)
#     ratings.append(rating.text)
# Out:
# [[<a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" data-t="threadLink" data-t-click="" href="https://www.dealabs.com/bons-plans/lot-de-2-ampoules-osram-w5w-12v-2426209" title="Lot de 2 ampoules halogène Osram OS2825-02B - 12V, W5W">Lot de 2 ampoules halogène Osram OS2825-02B - 12V, W5W</a>, <a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" data-t="threadLink" data-t-click="" href="https://www.dealabs.com/bons-plans/steam-r-type-final-2-deluxe-2426206" title="Jeu R-Type Final 2 sur PC (Dématérialisé)">Jeu R-Type Final 2 sur PC (Dématérialisé)</a>, <a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" data-t="threadLink" data-t-click="" href="https://www.dealabs.com/bons-plans/levis-mini-crossbody-solid-red-batwing-homme-taille-unique-2426205" title="Sac bandoulière Levi's Mini Crossbody Solid pour Homme - Noir">Sac bandoulière Levi's Mini Crossbody Solid pour Homme - Noir</a>, <a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" data-t="threadLink" data-t-click="" href="https://www.dealabs.com/bons-plans/entree-gratuite-au-musee-de-la-premiere-guerre-mondiale-jean-denise-letaille-1917-bullecourt-62-2426199" title="Entrée gratuite au Musée de la Première Guerre Mondiale Jean &amp; Denise Letaille 1917 - Bullecourt (62)">Entrée gratuite au Musée de la Première Guerre Mondiale Jean &amp; Denise Letaille 1917 - Bullecourt (62)</a>, <a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" data-t="threadLink" data-t-click="" href="https://www.dealabs.com/bons-plans/2-bouteilles-de-vin-jp-chenet-ice-edition-achetee-1-jeu-offert-2426198" title="2 bouteilles de vin JP CHENET ICE EDITION achetées = 1 jeu de société offert (Via formulaire)">2 bouteilles de vin JP CHENET ICE EDITION achetées = 1 jeu de société offert (Via formulaire)</a>, <a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" data-t="threadLink" data-t-click="" href="https://www.dealabs.com/bons-plans/lot-de-212-stickers-vendeur-tiers-2426196" title="Lot de 212 stickers (Vendeur tiers)">Lot de 212 stickers (Vendeur tiers)</a>, <a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" data-get-code-and-visit-site='{"blankPageUrl":"https://www.dealabs.com/codes-promo/5eur-offert-pour-une-commande-de-boulangerie-2426195","selfPageUrl":"https://www.dealabs.com/visit/homenew/2426195","id":2426195,"isOffer":false}' data-handler="get-code-and-visit-site" data-t="threadLink" data-t-click="" href="https://www.dealabs.com/codes-promo/5eur-offert-pour-une-commande-de-boulangerie-2426195" title="[Sous Conditions] 5€ de réduction dès 15€ d'achat pour une commande de Boulangerie">[Sous Conditions] 5€ de réduction dès 15€ d'achat pour une commande de Boulangerie</a>, <a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" data-t="threadLink" data-t-click="" href="https://www.dealabs.com/bons-plans/2-jeux-haba-achetes-1-jeu-sauve-avec-yoti-et-un-jeu-offert-2426193" title="2 jeux HABA achetés (minimum 20€) = jeu Famille bric-à-brac ou Pyramide d’animaux offert (Via formulaire)">2 jeux HABA achetés (minimum 20€) = jeu Famille bric-à-brac ou Pyramide d’animaux offert (Via formulaire)</a>, <a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" data-t="threadLink" data-t-click="" href="https://www.dealabs.com/bons-plans/anciens-nouveaux-abonnes-3-mois-dabonnement-gratuits-a-qobuz-studio-2426191" title="[Anciens / Nouveaux Abonnés] 3 mois d'abonnement gratuits à Qobuz Studio">[Anciens / Nouveaux Abonnés] 3 mois d'abonnement gratuits à Qobuz Studio</a>, <a class="cept-tt thread-link linkPlain thread-title--list js-thread-title" data-t="threadLink" data-t-click="" href="https://www.dealabs.com/bons-plans/siemens-machine-cafe-automatique-eq-700-odr-2426189" title="Machine à café automatique Siemens TQ705R03 EQ.700 Intégral (Via 150€ d'ODR)">Machine à café automatique Siemens TQ705R03 EQ.700 Intégral (Via ...

# %%
# <div class="new_info_next">
#      <input type="hidden" value="133" id="new_id" class="new_id">
#      <input type="hidden" value="0" id="default_pe" class="default_pe">
# </div>
title=[]
link=[]
degres=[]
price = []

temp = ["text--color-charcoal", "vote-temp--warm", "vote-temp--cold", "vote-temp--colder", "vote-temp--hot"]
reduc=["l","1"]

info = soup.find_all("div", {"class": "threadGrid thread-clickRoot"})

for infos in info:
    titre = infos.find_all("a", {"class": "cept-tt thread-link linkPlain thread-title--list js-thread-title"})
    for inf in titre:
        title.append(inf.get('title'))
        link.append(inf.get('href'))
for degre in info:
    for deg in temp:
        temperature = degre.find_all("span", {"class": f"cept-vote-temp vote-temp {deg}"})
        for t in temperature:
            degres.append(t.text.strip())
            

for prix in info:
    for red in reduc:
        cost = prix.find_all("span", {"class": f"thread-price text--b cept-tp size--all-{red} size--fromW3-xl"})
        free = prix.find_all("span", {"class": "overflow--fade"})
        if not cost:
            for money in free:
                price.append(money.text.strip())
        else:
            for n in cost:
                price.append(n.text.strip())
      
        
                   
df_link=pd.DataFrame(link)
df_link.rename(columns={0: "lien"},inplace=True)        
df_link = df_link.reset_index(drop=True)   
    
df_titre=pd.DataFrame(title)    
df_titre.rename(columns={0: "titre"},inplace=True)
df_titre = df_titre.reset_index(drop=True)

df_temperature = pd.DataFrame(degres)
df_temperature.rename(columns={0: "temperature"},inplace=True) 
df_temperature = df_temperature.reset_index(drop=True)



df_price = pd.DataFrame(price)
df_price.rename(columns={0: "prix"},inplace=True)
df_price = df_price.iloc[:-2:2]
df_price = df_price.reset_index(drop=True)



df_final = pd.concat([df_titre, df_temperature, df_price, df_link],axis=1)
df_final
# Out:
#                                                 titre temperature  \
# 0   Lot de 2 ampoules halogène Osram OS2825-02B - ...     Nouveau
# 1           Jeu R-Type Final 2 sur PC (Dématérialisé)         -4°
# 2   Sac bandoulière Levi's Mini Crossbody Solid po...         18°
# 3   Entrée gratuite au Musée de la Première Guerre...        129°
# 4   2 bouteilles de vin JP CHENET ICE EDITION ache...         -4°
# 5                 Lot de 212 stickers (Vendeur tiers)         27°
# 6   [Sous Conditions] 5€ de réduction dès 15€ d'ac...         10°
# 7   2 jeux HABA achetés (minimum 20€) = jeu Famill...         16°
# 8   [Anciens / Nouveaux Abonnés] 3 mois d'abonneme...         94°
# 9   Machine à café automatique Siemens TQ705R03 EQ...        -40°
# 10  Barrettes Mémoire RAM G.SKILL Trident Z5 Silve...         49°
# 11  Jeu Color battle offert dès 59€ d'achat (janod...        -26°
# 12                   8€ de réduction dès 40€ d'achats        -22°
# 13                         Râpe fine Microplane 46620        -50°
# 14  T-shirt Levi's Original à manches longues pour...         93°
# 15  SuperTotalCarnage! gratuit sur PC (Dématériali...         46°
# 16  Bas de jogging Aurique pour Femme - Tailles 36...         45°
# 17  TV 58" Philips 58PUS8517 - LED, 4K UHD, 50 Hz,...         52°
# 18  Écouteurs sans-fil Sony WF-C500 - Compatible a...         52°
# 19  Pack de démarrage Philips Hue : 2 Ampoules con...        -36°
#
#                          prix  \
# 0                       0,60€
# 1                      23,99€
# 2                      11,99€
# 3                     GRATUIT
# 4
# 5                       4,90€
# 6   - 5€Codes promo Deliveroo
# 7
# 8                     GRATUIT
# 9                        865€
# 10                    225,78€
# 11
# 12      - 8€Codes promo Vib's
# 13                     21,95€
# 14                     17,50€
# 15       Bons plans Indiegala
# 16                      7,50€
# 17                    699,99€
# 18                     40,30€
# 19                        NaN
#
#                                                  lien
# 0   https://www.dealabs.com/bons-plans/lot-de-2-am...
# 1   https://www.dealabs.com/bons-plans/steam-r-typ...
# 2   https://www.dealabs.com/bons-plans/levis-mini-...
# 3   https://www.dealabs.com/bons-plans/entree-grat...
# 4   https://www.dealabs.com/bons-plans/2-bouteille...
# 5   https://www.dealabs.com/bons-plans/lot-de-212-...
# 6   https://www.dealabs.com/codes-promo/5eur-offer...
# 7   https://www.dealabs.com/bons-plans/2-jeux-haba...
# 8   https://www.dealabs.com/bons-plans/anciens-nou...
# 9   https://www.dealabs.com/bons-plans/siemens-mac...
# 10  https://www.dealabs.com/bons-plans/barrettes-m...
# 11  https://www.dealabs.com/codes-promo/jeu-color-...
# 12  https://www.dealabs.com/codes-promo/la-team-vi...
# 13  https://www.dealabs.com/bons-plans/rape-microp...
# 14  https://www.dealabs.com/bons-plans/t-shirt-lev...
# 15  https://www.dealabs.com/bons-plans/supertotalc...
# 16  https://www.dealabs.com/bons-plans/aurique-bas...
# 17  https://www.dealabs.com/bons-plans/la-tv-phili...
# 18  https://www.dealabs.com/bons-plans/sony-wf-c50...
# 19  https://www.dealabs.com/bons-plans/philips-hue...

# %%
df_final['titre'] = df_final['titre'].str.lower()
df_final['titre'] = df_final['titre'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
df_final['prix'] = df_final['prix'].str.lower()
df_final
# Out:
#                                                 titre temperature  \
# 0   lot de 2 ampoules halogene osram os2825-02b - ...     Nouveau
# 1           jeu r-type final 2 sur pc (dematerialise)         -4°
# 2   sac bandouliere levi's mini crossbody solid po...         18°
# 3   entree gratuite au musee de la premiere guerre...        129°
# 4   2 bouteilles de vin jp chenet ice edition ache...         -4°
# 5                 lot de 212 stickers (vendeur tiers)         27°
# 6   [sous conditions] 5 de reduction des 15 d'acha...         10°
# 7   2 jeux haba achetes (minimum 20) = jeu famille...         16°
# 8   [anciens / nouveaux abonnes] 3 mois d'abonneme...         94°
# 9   machine a cafe automatique siemens tq705r03 eq...        -40°
# 10  barrettes memoire ram g.skill trident z5 silve...         49°
# 11  jeu color battle offert des 59 d'achat (janod....        -26°
# 12                     8 de reduction des 40 d'achats        -22°
# 13                         rape fine microplane 46620        -50°
# 14  t-shirt levi's original a manches longues pour...         93°
# 15  supertotalcarnage! gratuit sur pc (demateriali...         46°
# 16  bas de jogging aurique pour femme - tailles 36...         45°
# 17  tv 58" philips 58pus8517 - led, 4k uhd, 50 hz,...         52°
# 18  ecouteurs sans-fil sony wf-c500 - compatible a...         52°
# 19  pack de demarrage philips hue : 2 ampoules con...        -36°
#
#                          prix  \
# 0                       0,60€
# 1                      23,99€
# 2                      11,99€
# 3                     gratuit
# 4
# 5                       4,90€
# 6   - 5€codes promo deliveroo
# 7
# 8                     gratuit
# 9                        865€
# 10                    225,78€
# 11
# 12      - 8€codes promo vib's
# 13                     21,95€
# 14                     17,50€
# 15       bons plans indiegala
# 16                      7,50€
# 17                    699,99€
# 18                     40,30€
# 19                        NaN
#
#                                                  lien
# 0   https://www.dealabs.com/bons-plans/lot-de-2-am...
# 1   https://www.dealabs.com/bons-plans/steam-r-typ...
# 2   https://www.dealabs.com/bons-plans/levis-mini-...
# 3   https://www.dealabs.com/bons-plans/entree-grat...
# 4   https://www.dealabs.com/bons-plans/2-bouteille...
# 5   https://www.dealabs.com/bons-plans/lot-de-212-...
# 6   https://www.dealabs.com/codes-promo/5eur-offer...
# 7   https://www.dealabs.com/bons-plans/2-jeux-haba...
# 8   https://www.dealabs.com/bons-plans/anciens-nou...
# 9   https://www.dealabs.com/bons-plans/siemens-mac...
# 10  https://www.dealabs.com/bons-plans/barrettes-m...
# 11  https://www.dealabs.com/codes-promo/jeu-color-...
# 12  https://www.dealabs.com/codes-promo/la-team-vi...
# 13  https://www.dealabs.com/bons-plans/rape-microp...
# 14  https://www.dealabs.com/bons-plans/t-shirt-lev...
# 15  https://www.dealabs.com/bons-plans/supertotalc...
# 16  https://www.dealabs.com/bons-plans/aurique-bas...
# 17  https://www.dealabs.com/bons-plans/la-tv-phili...
# 18  https://www.dealabs.com/bons-plans/sony-wf-c50...
# 19  https://www.dealabs.com/bons-plans/philips-hue...

# %%
df_final['prix'] = df_final['prix'].replace('', 'none')
df_final['prix'] = df_final['prix'].fillna(0)
df_final['temperature'] = df_final['temperature'].fillna(0)
df_final['prix'] = df_final['prix'].astype(str)
df_final
# Out:
#                                                 titre temperature  \
# 0   lot de 2 ampoules halogene osram os2825-02b - ...     Nouveau
# 1           jeu r-type final 2 sur pc (dematerialise)         -4°
# 2   sac bandouliere levi's mini crossbody solid po...         18°
# 3   entree gratuite au musee de la premiere guerre...        129°
# 4   2 bouteilles de vin jp chenet ice edition ache...         -4°
# 5                 lot de 212 stickers (vendeur tiers)         27°
# 6   [sous conditions] 5 de reduction des 15 d'acha...         10°
# 7   2 jeux haba achetes (minimum 20) = jeu famille...         16°
# 8   [anciens / nouveaux abonnes] 3 mois d'abonneme...         94°
# 9   machine a cafe automatique siemens tq705r03 eq...        -40°
# 10  barrettes memoire ram g.skill trident z5 silve...         49°
# 11  jeu color battle offert des 59 d'achat (janod....        -26°
# 12                     8 de reduction des 40 d'achats        -22°
# 13                         rape fine microplane 46620        -50°
# 14  t-shirt levi's original a manches longues pour...         93°
# 15  supertotalcarnage! gratuit sur pc (demateriali...         46°
# 16  bas de jogging aurique pour femme - tailles 36...         45°
# 17  tv 58" philips 58pus8517 - led, 4k uhd, 50 hz,...         52°
# 18  ecouteurs sans-fil sony wf-c500 - compatible a...         52°
# 19  pack de demarrage philips hue : 2 ampoules con...        -36°
#
#                          prix  \
# 0                       0,60€
# 1                      23,99€
# 2                      11,99€
# 3                     gratuit
# 4                        none
# 5                       4,90€
# 6   - 5€codes promo deliveroo
# 7                        none
# 8                     gratuit
# 9                        865€
# 10                    225,78€
# 11                       none
# 12      - 8€codes promo vib's
# 13                     21,95€
# 14                     17,50€
# 15       bons plans indiegala
# 16                      7,50€
# 17                    699,99€
# 18                     40,30€
# 19                          0
#
#                                                  lien
# 0   https://www.dealabs.com/bons-plans/lot-de-2-am...
# 1   https://www.dealabs.com/bons-plans/steam-r-typ...
# 2   https://www.dealabs.com/bons-plans/levis-mini-...
# 3   https://www.dealabs.com/bons-plans/entree-grat...
# 4   https://www.dealabs.com/bons-plans/2-bouteille...
# 5   https://www.dealabs.com/bons-plans/lot-de-212-...
# 6   https://www.dealabs.com/codes-promo/5eur-offer...
# 7   https://www.dealabs.com/bons-plans/2-jeux-haba...
# 8   https://www.dealabs.com/bons-plans/anciens-nou...
# 9   https://www.dealabs.com/bons-plans/siemens-mac...
# 10  https://www.dealabs.com/bons-plans/barrettes-m...
# 11  https://www.dealabs.com/codes-promo/jeu-color-...
# 12  https://www.dealabs.com/codes-promo/la-team-vi...
# 13  https://www.dealabs.com/bons-plans/rape-microp...
# 14  https://www.dealabs.com/bons-plans/t-shirt-lev...
# 15  https://www.dealabs.com/bons-plans/supertotalc...
# 16  https://www.dealabs.com/bons-plans/aurique-bas...
# 17  https://www.dealabs.com/bons-plans/la-tv-phili...
# 18  https://www.dealabs.com/bons-plans/sony-wf-c50...
# 19  https://www.dealabs.com/bons-plans/philips-hue...

# %%
df_final = df_final.to_dict('records')
df_final
# Out:
# [{'titre': 'lot de 2 ampoules halogene osram os2825-02b - 12v, w5w',
#   'temperature': 'Nouveau',
#   'prix': '0,60€',
#   'lien': 'https://www.dealabs.com/bons-plans/lot-de-2-ampoules-osram-w5w-12v-2426209'},
#  {'titre': 'jeu r-type final 2 sur pc (dematerialise)',
#   'temperature': '-4°',
#   'prix': '23,99€',
#   'lien': 'https://www.dealabs.com/bons-plans/steam-r-type-final-2-deluxe-2426206'},
#  {'titre': "sac bandouliere levi's mini crossbody solid pour homme - noir",
#   'temperature': '18°',
#   'prix': '11,99€',
#   'lien': 'https://www.dealabs.com/bons-plans/levis-mini-crossbody-solid-red-batwing-homme-taille-unique-2426205'},
#  {'titre': 'entree gratuite au musee de la premiere guerre mondiale jean & denise letaille 1917 - bullecourt (62)',
#   'temperature': '129°',
#   'prix': 'gratuit',
#   'lien': 'https://www.dealabs.com/bons-plans/entree-gratuite-au-musee-de-la-premiere-guerre-mondiale-jean-denise-letaille-1917-bullecourt-62-2426199'},
#  {'titre': '2 bouteilles de vin jp chenet ice edition achetees = 1 jeu de societe offert (via formulaire)',
#   'temperature': '-4°',
#   'prix': 'none',
#   'lien': 'https://www.dealabs.com/bons-plans/2-bouteilles-de-vin-jp-chenet-ice-edition-achetee-1-jeu-offert-2426198'},
#  {'titre': 'lot de 212 stickers (vendeur tiers)',
#   'temperature': '27°',
#   'prix': '4,90€',
#   'lien': 'https://www.dealabs.com/bons-plans/lot-de-212-stickers-vendeur-tiers-2426196'},
#  {'titre': "[sous conditions] 5 de reduction des 15 d'achat pour une commande de boulangerie",
#   'temperature': '10°',
#   'prix': '- 5€codes promo deliveroo',
#   'lien': 'https://www.dealabs.com/codes-promo/5eur-offert-pour-une-commande-de-boulangerie-2426195'},
#  {'titre': '2 jeux haba achetes (minimum 20) = jeu famille bric-a-brac ou pyramide danimaux offert (via formulaire)',
#   'temperature': '16°',
#   'prix': 'none',
#   'lien': 'https://www.dealabs.com/bons-plans/2-jeux-haba-achetes-1-jeu-sauve-avec-yoti-et-un-jeu-offert-2426193'},
#  {'titre': "[anciens / nouveaux abonnes] 3 mois d'abonnement gratuits a qobuz studio",
#   'temperature': '94°',
#   'prix': 'gratuit',
#   'lien': 'https://www.dealabs.com/bons-plans/anciens-nouveaux-abonnes-3-mois-dabonnement-gratuits-a-qobuz-studio-2426191'},
#  {'titre': "machine a cafe automatique siemens tq705r03 eq.700 integral (via 150 d'odr)",
#   'temperature': '-40°',
#   'prix': '865€',
#   'lien': 'https://www.dealabs.com/bons-plans/siemens-machine-cafe-automatique-eq-700-odr-2426189'},
#  {'titre': 'barrettes memoire ram g.skill trident z5 silver - 32go (2x16go), ddr5, 6000mhz, cl36 (f5-6000j3636f16gx2-tz5s)',
#   'temperature': '49°',
#   'prix': '225,78€',
#   'lien': 'https://www.dealabs.com/bons-plans/barrettes-memoire-ram-gskill-trident-z5-silver-32go-2x16go-6000mhz-cl36-f5-6000j3636f16gx2-tz5s-2426190'},
#  {'titre': "jeu color battle offert des 59 d'achat (janod.com)",
#   'temperature': '-26°',
#   'prix': 'none',
#   'lien': 'https://www.dealabs.com/codes-promo/jeu-color-battle-gratuit-pour-59euros-dachat-sur-janodcom-2426188'},
#  {'titre': "8 de reduction des 40 d'achats",
#   'temperature': '-22°',
#   'prix': "- 8€codes promo vib's",
#   'lien': 'https://www.dealabs.com/codes-promo/la-team-vibs-vous-gate-2426187'},
#  {'titre': 'rape fine microplane 46620',
#   'temperature': '-50°',
#   'prix': '21,95€',
#   'lien': 'https://www.dealabs.com/bons-plans/rape-microplane-2426186'},
#  {'titre': "t-shirt levi's original a manches longues pour homme - tailles s a xxl",
#   'temperature': '93°',
#   'prix': '17,50€',
#   'lien': 'https://www.dealabs.com/bons-plans/t-shirt-levis-original-manches-longues-tailles-s-a-xxl-2426185'},
#  {'titre': 'supertotalcarnage! gratuit sur pc (dematerialise - drm-free)',
#   'temperature': '46°',
#   'prix': 'bons plans indiegala',
#   'lien': 'https://www.dealabs.com/bons-plans/supertotalcarnage-gratuit-sur-pc-dematerialise-drm-free-2426184'},
#  {'titre': 'bas de jogging aurique pour femme - tailles 36 a 44',
#   'temperature': '45°',
#   'prix': '7,50€',
#   'lien': 'https://www.dealabs.com/bons-plans/aurique-bas-de-jogging-court-bande-laterale-femme-2426183'},
#  {'titre': 'tv 58" philips 58pus8517 - led, 4k uhd, 50 hz, hdr, dolby vision, android tv + 90 offerts en carte cadeau',
#   'temperature': '52°',
#   'prix': '699,99€',
#   'lien': 'https://www.dealabs.com/bons-plans/la-tv-philips-4k-est-en-promotion-en-ce-moment-chez-darty-2424796'},
#  {'titre': 'ecouteurs sans-fil sony wf-c500 - compatible assistants vocaux',
#   'temperature': '52°',
#   'prix': '40,30€',
#   'lien': 'https://www.dealabs.com/bons-plans/sony-wf-c500-true-wireless-headphones-jusqua-20-heures-dautonomie-avec-etui-de-charge-compatible-avec-lassistant-vocal-2426177'},
#  {'titre': 'pack de demarrage philips hue : 2 ampoules connectees e27 white + pont de connexion + telecommande variateur + prise connectee',
#   'temperature': '-36°',
#   'prix': '0',
#   'lien': 'https://www.dealabs.com/bons-plans/philips-hue-pack-e27-bridge-prise-2426178'}]

# %%
df_final[0]
# Out:
# {'titre': 'lot de 2 ampoules halogene osram os2825-02b - 12v, w5w',
#  'temperature': 'Nouveau',
#  'prix': '0,60€',
#  'lien': 'https://www.dealabs.com/bons-plans/lot-de-2-ampoules-osram-w5w-12v-2426209'}

# %%
todo=[]

for i in df_final:
    substring = ["anciens","Carte","Jouet"]
    for s in substring:
        if s in i["titre"]:
            todo.append(i)
        elif s in i["prix"]:
            todo.append(i)
todo
# Out:
# [{'titre': "[anciens / nouveaux abonnes] 3 mois d'abonnement gratuits a qobuz studio",
#   'temperature': '94°',
#   'prix': 'gratuit',
#   'lien': 'https://www.dealabs.com/bons-plans/anciens-nouveaux-abonnes-3-mois-dabonnement-gratuits-a-qobuz-studio-2426191'}]

# %%
Titles = todo[0]["titre"]
Temperatures = todo[0]["temperature"]
prix = todo[0]["prix"]
Liens = todo[0]["lien"]

# %%
import smtplib
import ssl
from email.message import EmailMessage

# Define email sender and receiver
email_sender = 'z.mohamedpro@gmail.com'
email_password = 'dvpgwkatxnmgayrd'
email_receiver = 'z.mohamedpro@gmail.com'

# Set the subject and body of the email
subject = 'DEALABS OFFRE'
body = f"""
Hey beau gosse, 
    voici le titre de l'annonce : {Titles}
    voici la température : {Temperatures}
    voici le prix : {prix}
    et enfin voici le lien pour te rediriger vers l'annonce, FAIS VITE : {Liens}
"""

em = EmailMessage()
em['From'] = email_sender
em['To'] = email_receiver
em['Subject'] = subject
em.set_content(body)

# Add SSL (layer of security)
context = ssl.create_default_context()

# Log in and send the email
with smtplib.SMTP_SSL('smtp.gmail.com', 465, context=context) as smtp:
    smtp.login(email_sender, email_password)
    smtp.sendmail(email_sender, email_receiver, em.as_string())

# %%
# z=[]
# for i in df_final["titre"].iloc:
#     z.append(i)
    
# # substring = "Carte"    
# # # z[1]

# # if substring in z[1]:
# #     print("Found!")
# # else:
# #     print("Not found!")
    
# for j in range(len(z)):
#     substring = ["Carte","Jouet"]   
#     for s in substring:
#         if s in z[j]:
#             print(z[j])

# %%
# first_row = df_final.iloc[0].tolist()
# first_row

# %%
# p=[]

# w = ["text--color-charcoal", "vote-temp--warm", "vote-temp--cold", "vote-temp--colder", "vote-temp--hot"]
# # cept-vote-temp vote-temp text--color-charcoal
# # cept-vote-temp vote-temp vote-temp--warm
# temp = soup.find_all("div", {"class": "threadGrid thread-clickRoot"})
# for t in temp:
#     for x in w:
#         test2 = t.find_all("span", {"class": f"cept-vote-temp vote-temp {x}"})
#         for j in test2:
#             p.append(j.text.strip())
# #     liste_titre = [elt.string.strip() for elt in test2]
# df = pd.DataFrame(p)
# df    

# #     print(liste_titre)
# #     for t1 in test2:
# #          print(t1.get('title'))

# %%
# price = []

# reduc=["l","1"]
# # text--color-greyShade size--all-s
# infoss = soup.find_all("div", {"class": "threadGrid thread-clickRoot"})
# for prix in infoss:
#     for red in reduc:
#         cost = prix.find_all("span", {"class": f"thread-price text--b cept-tp size--all-{red} size--fromW3-xl"})
#         test = prix.find_all("span", {"class": "overflow--fade"})
#         if not cost:
#             for money in test:
#                 price.append(money.text.strip())
#         else:
#             for n in cost:
#                 price.append(n.text.strip())
# df_price = pd.DataFrame(price)
# df_price = df_price.iloc[:-2:2]
# df_price = df_price.reset_index(drop=True)
# df_price

# %%
# time = soup.find_all("div", {"class": "threadGrid thread-clickRoot"})
# for times in time:
#     test3 = times.find_all("span", {"class": "hide--toW3"})
#     for k in test3:
#         display(k.text.strip())
